# %% [markdown]
# ## Ai For Route Planning Using DRL (PPO VS DDQN)
#
# This Jupyter notebook presents a detailed simulation environment for an Unmanned Aerial Vehicle (UAV) navigation system using reinforcement learning techniques. The simulation is designed to optimize and evaluate UAV pathfinding capabilities in a controlled environment featuring obstacles and no-fly zones.
#
# ### Key Components:
#
# 1. **Custom Environment**: The simulation leverages a custom Gym environment tailored for UAV operations. This environment includes dynamic elements such as obstacles, no-fly zones, and a goal position that the UAV must navigate to.
#
# 2. **Deep Reinforcement Learning Models**:
#     - **Proximal Policy Optimization (PPO)**: Implements the PPO algorithm to train an agent with a policy-based method, focusing on learning a policy that dictates the action to take based on the current state.
#     - **Double Deep Q-Network (DDQN)**: Utilizes a value-based approach with a Q-network to estimate the optimal action-value function, with a target network to stabilize training.
#
# 3. **Simulation and Visualization**: The notebook includes functions to simulate UAV flights and visualize the paths taken by the UAV, helping to illustrate the effectiveness of the implemented learning algorithms.
#
# 4. **Evaluation and Hyperparameter Tuning**:
#     - The performance of the models is assessed through the average rewards over multiple test episodes.
#     - Hyperparameter optimization is conducted using Optuna to find the most effective learning rate, batch size, epsilon, and gamma values for the Q-network.
#
# ### Objectives:
# The main objectives of this notebook are to:
# - Develop and refine reinforcement learning models for autonomous UAV navigation.
# - Visualize UAV paths to assess model performance.
# - Optimize learning parameters to enhance UAV decision-making capabilities in complex environments.
#
# This notebook serves as a comprehensive guide to applying advanced reinforcement learning techniques for UAV navigation, highlighting model development, training, evaluation, and optimization steps.

# %%
import gym  # Gym provides the environment and spaces definitions for reinforcement learning tasks.
from gym import spaces  # Spaces define the types of valid action and observation spaces available in Gym.

import numpy as np  # NumPy is used for numerical operations and handling arrays efficiently.

import matplotlib.pyplot as plt  # Pyplot from Matplotlib is used for creating static, interactive, and animated visualizations.
import matplotlib.patches as patches  # Patches are used for drawing shapes, useful for visualizing obstacles and no-fly zones.

from stable_baselines3 import PPO  # Stable Baselines3 provides the PPO algorithm, a modern reinforcement learning model.
from stable_baselines3.common.env_util import make_vec_env  # Utility to create vectorized environments.
from stable_baselines3.common.evaluation import evaluate_policy  # Utility for evaluating the performance of a policy.

import time  # Used for managing time-related tasks, such as delays between rendering frames.

from PIL import Image  # PIL is used for opening, manipulating, and saving many different image file formats.
from matplotlib.animation import FuncAnimation  # For creating animations, which are useful for visualizing the UAV's path.

import tensorflow as tf  # TensorFlow is used for building and training the neural network models.

from collections import deque  # Deque is a double-ended queue, useful for implementing efficient queues and stacks.
import random  # Provides functionalities for generating random numbers, crucial for stochastic processes in simulations.

import optuna  # Optuna is an optimization framework used for automating hyperparameter tuning tasks.

# %%
class UAVEnv(gym.Env):
    """Custom Environment that follows gym interface for a UAV."""
    metadata = {'render.modes': ['human']}
    
    def __init__(self, goal_position=np.array([10, 10, 10]), max_steps=100):
        super(UAVEnv, self).__init__()
        """
        Initializes the UAV environment.

        Parameters:
        - goal_position (np.array): The goal position for the UAV to reach.
        - max_steps (int): Maximum number of steps allowed in the environment.
        """
        
        # Bounds of the environment including z-axis
        self.env_bounds = (15, 15, 30)  
        self.goal_position = goal_position
        self.max_steps = max_steps
        self.current_step = 0
        
        # Initial state: x, y, z, dx, dy, dz
        self.state = np.array([0, 0, 0, 0, 0, 0])  
        self.previous_distance = np.linalg.norm(self.state[:3] - self.goal_position)
        self.path = []
        
        # Adding no-fly zones
        self.no_fly_zones = [
            {'type': 'rectangle', 'position': (7.5, 2.5, 15), 'width': 2, 'height': 2, 'depth': 15}
        ]
        self.obstacles = [
            {'type': 'rectangle', 'position': (2, 2, 15), 'width': 1, 'height': 1, 'depth': 15},
            {'type': 'circle', 'position': (7.5, 7.5, 20), 'radius': 1, 'depth': 20},
            {'type': 'ellipse', 'position': (2.5, 7.5, 25), 'width': 2, 'height': 1, 'depth': 25}
        ]
        self.action_space = spaces.Discrete(6)
        self.observation_space = spaces.Box(low=np.array([-10, -10, 0, -1, -1, -1]),
                                            high=np.array([10, 10, 30, 1, 1, 1]),
                                            dtype=np.float32)

    def step(self, action):
        """
        Executes one step within the environment.

        Parameters:
        - action (int): The action to be taken.

        Returns:
        - state (np.array): The new state after taking the action.
        - reward (float): The reward obtained from taking the action.
        - done (bool): Whether the episode is done or not.
        - info (dict): Additional information.
        """
        reward = 0
        done = False
        
        self._take_action(action)
        self.current_step += 1
        self.path.append(self.state[:3].copy())
        done = self._is_done()
        reward = self._get_reward()
        
        # Logic to handle no-fly zones
        for zone in self.no_fly_zones:
            if self._in_no_fly_zone(self.state[:3], zone):
                reward -= 100  # Large penalty for entering no-fly zone
                done = True
        
        return np.array(self.state), reward, done, {}

    def reset(self):
        """
        Resets the environment to its initial state.

        Returns:
        - state (np.array): The initial state.
        """
        self.current_step = 0
        self.state = np.array([0, 0, 0, 0, 0, 0])  # Reset state
        self.previous_distance = np.linalg.norm(self.state[:3] - self.goal_position)
        self.path = []
        return np.array(self.state)

    
    """        #used for the PPO Model to download the GIF. Uncomment lines to use
    def render(self, mode='human'):
        if mode == 'human':
            #x = latitude, y = longitude, and z is the altitude.
            x, y, z, dx, dy, dz = self.state
            fig, ax = plt.subplots(figsize=(10, 10))

            # Goal and UAV positions
            ax.scatter(self.goal_position[0], self.goal_position[1], c='red', s=100, label='Goal', alpha=0.5)
            ax.scatter(x, y, c='blue', s=100, label='UAV', alpha=0.5)

            # UAV Path
            if self.path:
                path_array = np.array(self.path)
                ax.plot(path_array[:, 0], path_array[:, 1], label='Path', color='blue', alpha=0.6)

            # Axis limits
            ax.set_xlim(self.observation_space.low[0], self.observation_space.high[0])
            ax.set_ylim(self.observation_space.low[1], self.observation_space.high[1])

            # Labels and Title
            ax.set_xlabel('Latitude')
            ax.set_ylabel('Longitude')
            ax.set_title('UAV Navigation Environment')

            # Obstacles rendering
            for obstacle in self.obstacles:
                self._plot_obstacle(ax, obstacle, 'red')

            # No-fly zones rendering with a different color
            for zone in self.no_fly_zones:
                self._plot_obstacle(ax, zone, 'purple')  # Visualizing no-fly zones distinctly

            # Legend and Grid
            ax.legend()
            ax.grid(True)
            plt.show()"""
        
        #Used for the DDQN Model to download the Image. comment these lines to use the above PPO render function.
    def render(self, mode='rgb_array'):
        """
        Renders the environment.

        Parameters:
        - mode (str): Rendering mode ('rgb_array' for rendering to NumPy array).

        Returns:
        - frame (np.ndarray): Rendered frame as a NumPy array.
        """
        if mode == 'rgb_array':
            #x = latitude, y = longitude, and z is the altitude.
            x, y, z, dx, dy, dz = self.state
            fig, ax = plt.subplots(figsize=(10, 10))

            # Goal and UAV positions
            ax.scatter(self.goal_position[0], self.goal_position[1], c='red', s=100, label='Goal', alpha=0.5)
            ax.scatter(x, y, c='blue', s=100, label='UAV', alpha=0.5)

            # UAV Path
            if self.path:
                path_array = np.array(self.path)
                ax.plot(path_array[:, 0], path_array[:, 1], label='Path', color='blue', alpha=0.6)

            # Axis limits
            ax.set_xlim(self.observation_space.low[0], self.observation_space.high[0])
            ax.set_ylim(self.observation_space.low[1], self.observation_space.high[1])

            # Labels and Title
            ax.set_xlabel('Latitude')
            ax.set_ylabel('Longitude')
            ax.set_title('UAV Navigation Environment')

            # Obstacles rendering
            for obstacle in self.obstacles:
                self._plot_obstacle(ax, obstacle, 'red')

            # No-fly zones rendering with a different color
            for zone in self.no_fly_zones:
                self._plot_obstacle(ax, zone, 'purple')  # Visualizing no-fly zones distinctly

            # Legend and Grid
            ax.legend()
            ax.grid(True)

            # Convert the plot to a NumPy array
            fig.canvas.draw()
            frame = np.array(fig.canvas.renderer.buffer_rgba())
            plt.close(fig)

            return frame

        elif mode == 'human':
            # Render the environment using Matplotlib
            plt.show()
            
    
        

    def _plot_obstacle(self, ax, obstacle, color):
        """
        Helper function to plot obstacles.

        Parameters:
        - ax (matplotlib.axes.Axes): The matplotlib axes object.
        - obstacle (dict): Dictionary containing obstacle information.
        - color (str): Color of the obstacle.
        """
        if obstacle['type'] == 'rectangle':
            rect = patches.Rectangle((obstacle['position'][0] - obstacle['width']/2,
                                      obstacle['position'][1] - obstacle['height']/2),
                                     obstacle['width'], obstacle['height'],
                                     linewidth=1, edgecolor=color, facecolor=color, alpha=0.3)
            ax.add_patch(rect)
        elif obstacle['type'] == 'circle':
            circle = patches.Circle((obstacle['position'][0], obstacle['position'][1]),
                                    obstacle['radius'], linewidth=1,
                                    edgecolor=color, facecolor=color, alpha=0.3)
            ax.add_patch(circle)
        elif obstacle['type'] == 'ellipse':
            ellipse = patches.Ellipse((obstacle['position'][0], obstacle['position'][1]),
                                      obstacle['width'], obstacle['height'],
                                      linewidth=1, edgecolor=color, facecolor=color, alpha=0.3)
            ax.add_patch(ellipse)
            
            
            
    def _detect_collision(self, new_position):
        """
        Detects collision between the UAV and obstacles.

        Parameters:
        - new_position (np.array): The new position of the UAV.

        Returns:
        - collision (bool): True if collision detected, False otherwise.
        """
        for obstacle in self.obstacles:
            # Collision detection for rectangle
            if obstacle['type'] == 'rectangle':
                rect_min_x = obstacle['position'][0] - obstacle['width'] / 2
                rect_max_x = obstacle['position'][0] + obstacle['width'] / 2
                rect_min_y = obstacle['position'][1] - obstacle['height'] / 2
                rect_max_y = obstacle['position'][1] + obstacle['height'] / 2
                if rect_min_x <= new_position[0] <= rect_max_x and rect_min_y <= new_position[1] <= rect_max_y:
                    return True
            # Collision detection for circle
            elif obstacle['type'] == 'circle':
                distance = np.linalg.norm(np.array(obstacle['position'][:2]) - new_position[:2])
                if distance <= obstacle['radius']:
                    return True
            # Collision detection for ellipse
            elif obstacle['type'] == 'ellipse':
                # Simplified ellipse detection
                distance = np.linalg.norm(np.array(obstacle['position'][:2]) - new_position[:2])
                if distance <= max(obstacle['width'], obstacle['height']):
                    return True
        return False

    def _take_action(self, action):
        """
        Takes action based on the given action.

        Parameters:
        - action (int): The action to be taken by the UAV.
        """
        x, y, z, dx, dy, dz = self.state
        speed_change = 0.1
        if action == 0: dz += speed_change
        elif action == 1: dz -= speed_change
        elif action == 2: dx -= speed_change
        elif action == 3: dx += speed_change
        elif action == 4: dy += speed_change
        elif action == 5: dy -= speed_change
        damping_factor = 0.95
        dx *= damping_factor
        dy *= damping_factor
        dz *= damping_factor
        x += dx
        y += dy
        z += dz
        x = np.clip(x, self.observation_space.low[0], self.observation_space.high[0])
        y = np.clip(y, self.observation_space.low[1], self.observation_space.high[1])
        z = np.clip(z, self.observation_space.low[2], self.observation_space.high[2])
        self.state = np.array([x, y, z, dx, dy, dz])

        # New position based on current action
        new_position = np.array([x + dx, y + dy, z + dz])
        
        # Check for collision
        if self._detect_collision(new_position):
            # Handle collision (e.g., reset position, apply penalty, etc.)
            print("Collision detected! Taking avoidance measures.")
            # For example, undo the move which causes the collision
            dx = dy = dz = 0
        else:
            # Update state only if no collision
            self.state = np.array([x + dx, y + dy, z + dz, dx, dy, dz])

    def _get_proximity_penalty(self, current_position):
        """
        Computes the penalty for proximity to obstacles.

        Parameters:
        - current_position (np.array): Current position of the UAV.

        Returns:
        - penalty (float): The proximity penalty.
        """
        penalty = 0
        # Define a minimum safe distance
        safe_distance = 1.0
    
        for obstacle in self.obstacles:
            # Check proximity for rectangles
            if obstacle['type'] == 'rectangle':
                rect_min_x = obstacle['position'][0] - obstacle['width'] / 2 - safe_distance
                rect_max_x = obstacle['position'][0] + obstacle['width'] / 2 + safe_distance
                rect_min_y = obstacle['position'][1] - obstacle['height'] / 2 - safe_distance
                rect_max_y = obstacle['position'][1] + obstacle['height'] / 2 + safe_distance
                if rect_min_x <= current_position[0] <= rect_max_x and rect_min_y <= current_position[1] <= rect_max_y:
                    penalty += (safe_distance - min(abs(current_position[0] - rect_min_x),
                                                    abs(current_position[0] - rect_max_x),
                                                    abs(current_position[1] - rect_min_y),
                                                    abs(current_position[1] - rect_max_y)))
    
            # Proximity check for circles
            elif obstacle['type'] == 'circle':
                distance = np.linalg.norm(np.array(obstacle['position'][:2]) - current_position[:2])
                if distance < obstacle['radius'] + safe_distance:
                    penalty += (obstacle['radius'] + safe_distance - distance)
    
            # Proximity check for ellipses
            elif obstacle['type'] == 'ellipse':
                # Simplified ellipse proximity check
                distance = np.linalg.norm(np.array(obstacle['position'][:2]) - current_position[:2])
                if distance < max(obstacle['width'], obstacle['height']) + safe_distance:
                    penalty += (max(obstacle['width'], obstacle['height']) + safe_distance - distance)
    
        return penalty

    
    def _get_reward(self):
        """
        Computes the reward for the current state.

        Returns:
        - reward (float): The reward for the current state.
        """
        current_position = self.state[:3]
        goal_distance = np.linalg.norm(current_position - self.goal_position)
        if self.current_step == 0:
            self.previous_distance = goal_distance
        reward = self.previous_distance - goal_distance
        self.previous_distance = goal_distance
        speed_penalty = -np.linalg.norm(self.state[3:]) * 0.05
        if goal_distance < 1:
            reward += 100  # Large reward for reaching the goal
        return reward + speed_penalty

        # Check if UAV is too close to any obstacles and apply a penalty
        penalty_for_proximity_to_obstacles = -10 if self._detect_collision(self.state[:3]) else 0
    
        return reward + speed_penalty + penalty_for_proximity_to_obstacles

        proximity_penalty = self._get_proximity_penalty(self.state[:3])
        return reward + speed_penalty - proximity_penalty

    def _is_done(self):
        """
        Checks if the episode is done.

        Returns:
        - done (bool): True if the episode is done, False otherwise.
        """
        current_position = self.state[:3]
        goal_distance = np.linalg.norm(current_position - self.goal_position)
        if goal_distance < 1:
            print("Goal reached!")
            return True
        if self.current_step >= self.max_steps:
            print("Max steps exceeded.")
            return True

        if self._detect_collision(self.state[:3]):
            print("Collision with an obstacle!")
            return True
        return False
    
    def _in_no_fly_zone(self, position, zone):
        """
        Checks if the given position is within a specified no-fly zone.

        Parameters:
        - position (tuple): The position to be checked (x, y, z).
        - zone (dict): The definition of the no-fly zone.

        Returns:
        - in_zone (bool): True if the position is within the no-fly zone, False otherwise.
        """
        x, y, z = position
        zx, zy, zz = zone['position']

        if zone['type'] == 'rectangle':
            return (zx - zone['width']/2 <= x <= zx + zone['width']/2 and
                    zy - zone['height']/2 <= y <= zy + zone['height']/2 and
                    0 <= z <= zz)
        elif zone['type'] == 'circle':
            # Check if the point is within the radius of the circle on the xy-plane
            distance = np.sqrt((x - zx)**2 + (y - zy)**2)
            return distance <= zone['radius'] and 0 <= z <= zz
        elif zone['type'] == 'ellipse':
            # Check if the point is within the ellipse on the xy-plane
            distance = ((x - zx)**2 / (zone['width']/2)**2) + ((y - zy)**2 / (zone['height']/2)**2)
            return distance <= 1 and 0 <= z <= zz

        return False


    def seed(self, seed=None):
        """
        Sets the seed for the random number generator.

        Parameters:
        - seed (int or None): The seed value. If None, the seed is not set.
        """
        np.random.seed(seed)

# %%
# Usage of the UAVEnv environment

# Create an instance of the UAVEnv environment
env = UAVEnv()

# Reset the environment and get the initial state
state = env.reset()

# Iterate through a predefined number of steps (e.g., 50)
for _ in range(50):
    # Sample a random action from the action space
    action = env.action_space.sample()

    # Take a step in the environment using the sampled action
    state, reward, done, info = env.step(action)

    # Render the environment to visualize the UAV's navigation
    env.render()

    # Check if the episode is done
    if done:
        break
# Out:
# C:\Users\ammar\myuav\Lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
# Creating a vectorized environment with 4 parallel environments
env = make_vec_env(lambda: UAVEnv(), n_envs=4)

# Assuming you have your environment `env` already set up
# Initializing the PPO model with the MlpPolicy
model = PPO("MlpPolicy", 
            env, 
            learning_rate=0.0003805913356107848, 
            n_steps=64, 
            batch_size=32, 
            verbose=1)

# Training the model, you might want to increase the number of timesteps
model.learn(total_timesteps=150000)

# Evaluating the trained agent
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=20)
print(f"Mean reward: {mean_reward}")

# Close the environment when done
env.close()
# Out:
# Using cpu device
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 3.15     |
# | time/              |          |
# |    fps             | 3109     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 256      |
# ---------------------------------
# C:\Users\ammar\myuav\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74          |
# |    ep_rew_mean          | -16.4       |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.012844631 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 2.25        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 5.25        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 62.2         |
# |    ep_rew_mean          | -23.4        |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 3            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 0.0031504112 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.0388       |
# |    learning_rate        | 0.000381     |
# |    loss                 | 293          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00762     |
# |    value_loss           | 274          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68.2         |
# |    ep_rew_mean          | -16.7        |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0013870203 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 31.2         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00739     |
# |    value_loss           | 252          |
# ------------------------------------------
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.6       |
# |    ep_rew_mean          | -13.3      |
# | time/                   |            |
# |    fps                  | 690        |
# |    iterations           | 5          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 1280       |
# | train/                  |            |
# |    approx_kl            | 0.01765399 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | 0.55       |
# |    learning_rate        | 0.000381   |
# |    loss                 | 1.69       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0236    |
# |    value_loss           | 3.7        |
# ----------------------------------------
# Max steps exceeded.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.2        |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 676         |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.018804444 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.944       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 3.45        |
# -----------------------------------------
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.8        |
# |    ep_rew_mean          | -9.14       |
# | time/                   |             |
# |    fps                  | 668         |
# |    iterations           | 7           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.019393161 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.000381    |
# |    loss                 | 1.9         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.4        |
# |    ep_rew_mean          | -6.69       |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.017649032 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.525       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 2.33        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.9        |
# |    ep_rew_mean          | -4.91       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 9           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.016814234 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.565       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.69        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 64.3      |
# |    ep_rew_mean          | 2.62      |
# | time/                   |           |
# |    fps                  | 642       |
# |    iterations           | 10        |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 2560      |
# | train/                  |           |
# |    approx_kl            | 0.0185704 |
# |    clip_fraction        | 0.286     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.52     |
# |    explained_variance   | 0.388     |
# |    learning_rate        | 0.000381  |
# |    loss                 | 0.493     |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.0348   |
# |    value_loss           | 2.04      |
# ---------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.8         |
# |    ep_rew_mean          | 2.34         |
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 11           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0008984497 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.0933      |
# |    learning_rate        | 0.000381     |
# |    loss                 | 152          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000824    |
# |    value_loss           | 620          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.6        |
# |    ep_rew_mean          | 2.65        |
# | time/                   |             |
# |    fps                  | 636         |
# |    iterations           | 12          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008962137 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.24       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 1.68        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 8.5         |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 56.6         |
# |    ep_rew_mean          | 2.82         |
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 13           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0073618805 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -0.0737      |
# |    learning_rate        | 0.000381     |
# |    loss                 | 1.26         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0152      |
# |    value_loss           | 3.85         |
# ------------------------------------------
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 2.96        |
# | time/                   |             |
# |    fps                  | 630         |
# |    iterations           | 14          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.011121813 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.956       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 3.42        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.2        |
# |    ep_rew_mean          | 3.32        |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 15          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.008206019 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 1.01        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.1        |
# |    ep_rew_mean          | 3.44        |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 16          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.025238782 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.321       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 1.13        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.8        |
# |    ep_rew_mean          | 3.65        |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 17          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.010996179 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 1.45        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.6        |
# |    ep_rew_mean          | 4.81        |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 18          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.020036235 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.998       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 2.32        |
# -----------------------------------------
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.9         |
# |    ep_rew_mean          | 7.38         |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 19           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0032769507 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | -0.00944     |
# |    learning_rate        | 0.000381     |
# |    loss                 | 105          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0088      |
# |    value_loss           | 315          |
# ------------------------------------------
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 42.3          |
# |    ep_rew_mean          | 7.73          |
# | time/                   |               |
# |    fps                  | 610           |
# |    iterations           | 20            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00077905506 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.49         |
# |    explained_variance   | -0.00138      |
# |    learning_rate        | 0.000381      |
# |    loss                 | 316           |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00331      |
# |    value_loss           | 1.24e+03      |
# -------------------------------------------
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.2         |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 21           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0003393509 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 122          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 579          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.5         |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 22           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 8.844398e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 364          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000852    |
# |    value_loss           | 872          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.4         |
# |    ep_rew_mean          | 14.2         |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 23           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0025761242 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 177          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00557     |
# |    value_loss           | 290          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32           |
# |    ep_rew_mean          | 11.5         |
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 24           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0002736759 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 74.7         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 441          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.9         |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 25           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 7.644389e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.0707       |
# |    learning_rate        | 0.000381     |
# |    loss                 | 369          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000119    |
# |    value_loss           | 798          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 31.5          |
# |    ep_rew_mean          | 11.2          |
# | time/                   |               |
# |    fps                  | 604           |
# |    iterations           | 26            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 0.00070250826 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | 0.287         |
# |    learning_rate        | 0.000381      |
# |    loss                 | 343           |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00211      |
# |    value_loss           | 605           |
# -------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.6         |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 27           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0019106837 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 365          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00605     |
# |    value_loss           | 373          |
# ------------------------------------------
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 31.2          |
# |    ep_rew_mean          | 18.9          |
# | time/                   |               |
# |    fps                  | 602           |
# |    iterations           | 28            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.00022312603 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.49         |
# |    explained_variance   | 0.253         |
# |    learning_rate        | 0.000381      |
# |    loss                 | 194           |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.0017       |
# |    value_loss           | 869           |
# -------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.3         |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 29           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 7424         |
# | train/                  |              |
# |    approx_kl            | 8.626352e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.397        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 316          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000927    |
# |    value_loss           | 866          |
# ------------------------------------------
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30.1          |
# |    ep_rew_mean          | 22.3          |
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 30            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 0.00018117926 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | -0.295        |
# |    learning_rate        | 0.000381      |
# |    loss                 | 124           |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00143      |
# |    value_loss           | 400           |
# -------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 30.1          |
# |    ep_rew_mean          | 22.3          |
# | time/                   |               |
# |    fps                  | 602           |
# |    iterations           | 31            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 7936          |
# | train/                  |               |
# |    approx_kl            | 3.0101975e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 0.148         |
# |    learning_rate        | 0.000381      |
# |    loss                 | 550           |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000317     |
# |    value_loss           | 1.06e+03      |
# -------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.8         |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 32           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0006588183 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 68.4         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 496          |
# ------------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 23.4        |
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 33          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.003579994 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 167         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 706         |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 34          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.004408002 |
# |    clip_fraction        | 0.00508     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 299         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 384         |
# -----------------------------------------
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.7         |
# |    ep_rew_mean          | 21.3         |
# ...
# |    policy_gradient_loss | -0.00911  |
# |    value_loss           | 0.00576   |
# ---------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 23.1      |
# |    ep_rew_mean          | 116       |
# | time/                   |           |
# |    fps                  | 613       |
# |    iterations           | 572       |
# |    time_elapsed         | 238       |
# |    total_timesteps      | 146432    |
# | train/                  |           |
# |    approx_kl            | 0.0838774 |
# |    clip_fraction        | 0.245     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.244    |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.000381  |
# |    loss                 | -0.000659 |
# |    n_updates            | 5710      |
# |    policy_gradient_loss | -0.0168   |
# |    value_loss           | 0.00517   |
# ---------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 573         |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 146688      |
# | train/                  |             |
# |    approx_kl            | 0.040068127 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.111      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.036       |
# |    n_updates            | 5720        |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 574         |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 146944      |
# | train/                  |             |
# |    approx_kl            | 0.020097584 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0983     |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.000381    |
# |    loss                 | -0.00744    |
# |    n_updates            | 5730        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.0712      |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.1       |
# |    ep_rew_mean          | 116        |
# | time/                   |            |
# |    fps                  | 613        |
# |    iterations           | 575        |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 147200     |
# | train/                  |            |
# |    approx_kl            | 0.05021908 |
# |    clip_fraction        | 0.0621     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0972    |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.000381   |
# |    loss                 | 0.0703     |
# |    n_updates            | 5740       |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 0.13       |
# ----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 576         |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.070097074 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.000381    |
# |    loss                 | -0.0287     |
# |    n_updates            | 5750        |
# |    policy_gradient_loss | 0.0097      |
# |    value_loss           | 0.0307      |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 577         |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 147712      |
# | train/                  |             |
# |    approx_kl            | 0.011329434 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.183      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.000381    |
# |    loss                 | -0.0131     |
# |    n_updates            | 5760        |
# |    policy_gradient_loss | -0.00973    |
# |    value_loss           | 0.0444      |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.1         |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 578          |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 147968       |
# | train/                  |              |
# |    approx_kl            | 0.0075973747 |
# |    clip_fraction        | 0.0988       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.142       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.000381     |
# |    loss                 | 0.00736      |
# |    n_updates            | 5770         |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.0126       |
# ------------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 579         |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 148224      |
# | train/                  |             |
# |    approx_kl            | 0.008275531 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.000381    |
# |    loss                 | -0.0111     |
# |    n_updates            | 5780        |
# |    policy_gradient_loss | -0.00965    |
# |    value_loss           | 0.0316      |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.1         |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 580          |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 148480       |
# | train/                  |              |
# |    approx_kl            | 0.0049025365 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.173       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.000381     |
# |    loss                 | -0.0159      |
# |    n_updates            | 5790         |
# |    policy_gradient_loss | -0.00557     |
# |    value_loss           | 0.0125       |
# ------------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 581         |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 148736      |
# | train/                  |             |
# |    approx_kl            | 0.022475123 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.000381    |
# |    loss                 | 0.00312     |
# |    n_updates            | 5800        |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 0.0393      |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.1         |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 582          |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 148992       |
# | train/                  |              |
# |    approx_kl            | 0.0077876565 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.000381     |
# |    loss                 | -0.0111      |
# |    n_updates            | 5810         |
# |    policy_gradient_loss | -0.00815     |
# |    value_loss           | 0.0149       |
# ------------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 583         |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 149248      |
# | train/                  |             |
# |    approx_kl            | 0.019734673 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.161      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.000381    |
# |    loss                 | -0.0424     |
# |    n_updates            | 5820        |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 0.00543     |
# -----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23           |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 584          |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0130718285 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.000381     |
# |    loss                 | -0.00773     |
# |    n_updates            | 5830         |
# |    policy_gradient_loss | 0.00201      |
# |    value_loss           | 0.0167       |
# ------------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23           |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 585          |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 149760       |
# | train/                  |              |
# |    approx_kl            | 0.0051789503 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.128       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.000381     |
# |    loss                 | -0.0162      |
# |    n_updates            | 5840         |
# |    policy_gradient_loss | -0.00545     |
# |    value_loss           | 0.00522      |
# ------------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23         |
# |    ep_rew_mean          | 116        |
# | time/                   |            |
# |    fps                  | 613        |
# |    iterations           | 586        |
# |    time_elapsed         | 244        |
# |    total_timesteps      | 150016     |
# | train/                  |            |
# |    approx_kl            | 0.01341752 |
# |    clip_fraction        | 0.0422     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.105     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.000381   |
# |    loss                 | -0.0206    |
# |    n_updates            | 5850       |
# |    policy_gradient_loss | 0.00528    |
# |    value_loss           | 0.00264    |
# ----------------------------------------
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Mean reward: 116.47405699999999

# %% [markdown]
# *This code cell sets up a test environment and runs a simulation of the UAV navigating through the environment. It then visualizes the path of the UAV, including obstacles and no-fly zones, and saves the animation as a GIF file.*

# %%
# Create a single environment instance for testing
test_env = UAVEnv()

# Reset the environment and get the initial observation
obs = test_env.reset()

# Prepare to collect UAV's path for visualization
path_x, path_y = [], []

# Set the number of steps you want to watch
num_steps = 1000

for step in range(num_steps):
    # Append current UAV position to path
    path_x.append(obs[0])
    path_y.append(obs[1])
    
    # Predict the action with the highest probability using your model
    action, _ = model.predict(obs, deterministic=True)
    
    # Take the action in the environment
    obs, reward, done, info = test_env.step(action)
    
    # Render the environment (optional here, only for visual feedback in Jupyter)
    test_env.render()
    
    # Break the loop if the episode is done
    if done:
        print(f"Episode finished after {step + 1} timesteps")
        break
    
    # Pause a bit between frames for easier visualization (optional)
    time.sleep(0.05)

# Function to update the plot for each frame of the animation
def update(frame):
    """Update function for the animation."""
    ax.clear()
    ax.set_xlim((0, test_env.env_bounds[0]))
    ax.set_ylim((0, test_env.env_bounds[1]))

    # Plot target position
    ax.plot(test_env.goal_position[0], test_env.goal_position[1], 'ro', label='Target')

    # Plot obstacles
    for obstacle in test_env.obstacles:
        if obstacle['type'] == 'rectangle':
            rect = patches.Rectangle((obstacle['position'][0] - obstacle['width'] / 2,
                                      obstacle['position'][1] - obstacle['height'] / 2),
                                     obstacle['width'], obstacle['height'],
                                     linewidth=1, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
        elif obstacle['type'] == 'circle':
            circle = patches.Circle(obstacle['position'][:2], obstacle['radius'],
                                    linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(circle)
        elif obstacle['type'] == 'ellipse':
            ellipse = patches.Ellipse(obstacle['position'][:2], obstacle['width'],
                                      obstacle['height'], linewidth=1, edgecolor='g', facecolor='none')
            ax.add_patch(ellipse)
            
            
        
    for zone in test_env.no_fly_zones:
        if zone['type'] == 'rectangle':
            rect = patches.Rectangle((zone['position'][0] - zone['width'] / 2,
                                      zone['position'][1] - zone['height'] / 2),
                                     zone['width'], zone['height'],
                                     linewidth=1, edgecolor='purple', facecolor='purple', alpha=0.5)
            ax.add_patch(rect)

    # Plot UAV path up to the current frame
    ax.plot(path_x[:frame], path_y[:frame], 'b-', label='UAV Path')
    ax.legend()

    return ax

# Create the animation
fig, ax = plt.subplots(figsize=(6, 6))
anim = FuncAnimation(fig, update, frames=min(num_steps, len(path_x)), blit=False)

# Save the animation as a .gif
anim.save('UAV-with-no-fly-zone-LLA.gif', writer='pillow', fps=5)

plt.close(fig)  # Close the figure to prevent it from displaying in the notebook
# Out:
# Goal reached!
# Episode finished after 23 timesteps

# %% [markdown]
# This code defines a Q-learning neural network architecture (`QNetwork`) using TensorFlow's Keras API. It also initializes the environment (`UAVEnv`), sets up the training parameters, and implements the training loop.
#
# ### Neural Network Architecture
# The `QNetwork` class defines a neural network with two dense layers of 64 units each, followed by an output layer with `num_actions` units. ReLU activation functions are used for the hidden layers, while the output layer has no activation function.
#
# ### Initialization
# - The environment (`env`) and the Q-network (`q_network`) are initialized.
# - A target network (`target_network`) is created with the same architecture as the Q-network, and its weights are initialized to match those of the Q-network.
#
# ### Training Parameters
# - Adam optimizer with a learning rate of 0.001 is used.
# - The discount factor (`gamma`) is set to 0.99.
# - The replay buffer (`replay_buffer`) is a deque with a maximum length of 10,000.
# - The batch size for training (`batch_size`) is set to 32.
#
# ### Training Loop
# - The training loop runs for `num_episodes` episodes.
# - Within each episode:
#   - The environment is reset (`env.reset()`), and the initial state is obtained.
#   - The episode reward is initialized to 0, and the episode continues until termination.
#   - Within each step of the episode:
#     - An action is chosen using an epsilon-greedy policy.
#     - The chosen action is applied to the environment, and the next state, reward, and termination signal are obtained.
#     - The transition (state, action, reward, next_state, done) is stored in the replay buffer.
#     - If the replay buffer contains enough transitions, a minibatch is sampled from it.
#     - Target Q-values are computed using the target network.
#     - The Q-network is updated using the sampled minibatch and target Q-values.
#     - The target network is updated periodically by copying the weights from the Q-network.
#
# ### Episode Statistics
# - After each episode, the episode number and the total reward accumulated during the episode are printed.

# %%
# Define neural network architecture
class QNetwork(tf.keras.Model):
    def __init__(self, num_actions):
        super(QNetwork, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')
        self.output_layer = tf.keras.layers.Dense(num_actions, activation=None)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

# Initialize environment and neural network
env = UAVEnv()
num_actions = env.action_space.n
q_network = QNetwork(num_actions)
target_network = QNetwork(num_actions)
target_network.set_weights(q_network.get_weights())

# Define training parameters
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
gamma = 0.99  # Discount factor
batch_size = 32
replay_buffer = deque(maxlen=10000)

# Define the number of episodes for training
num_episodes = 1000

# Define exploration-exploitation trade-off parameter (epsilon)
epsilon = 0.1  # Adjust this as needed

# Initialize total steps counter
total_steps = 0

# Define the frequency of updating the target network
target_update_freq = 100  # Adjust this as needed

# Training loop
for episode in range(num_episodes):
    state = env.reset()
    episode_reward = 0
    done = False
    
    while not done:
        # Choose action using epsilon-greedy policy
        if np.random.rand() < epsilon:
            action = np.random.randint(num_actions)
        else:
            q_values = q_network(np.expand_dims(state, axis=0))
            action = np.argmax(q_values)

        # Take action
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward

        # Store transition in replay buffer
        replay_buffer.append((state, action, reward, next_state, done))
        state = next_state

        # Ensure replay buffer contains enough transitions before sampling
        if len(replay_buffer) >= batch_size:
            # Sample minibatch from replay buffer
            minibatch = random.sample(replay_buffer, batch_size)
            states, actions, rewards, next_states, dones = zip(*minibatch)

            # Compute target Q-values
            next_q_values = target_network(np.array(next_states))
            max_next_q_values = np.max(next_q_values, axis=1)
            targets = np.array(rewards) + (1 - np.array(dones)) * gamma * max_next_q_values

            # Update Q-network
            with tf.GradientTape() as tape:
                q_values = q_network(np.array(states))
                selected_q_values = tf.reduce_sum(q_values * tf.one_hot(actions, num_actions), axis=1)
                loss = tf.reduce_mean(tf.square(targets - selected_q_values))
            grads = tape.gradient(loss, q_network.trainable_variables)
            optimizer.apply_gradients(zip(grads, q_network.trainable_variables))

            # Update target network
            if total_steps % target_update_freq == 0:
                target_network.set_weights(q_network.get_weights())

    # Print episode statistics
    print(f"Episode: {episode}, Reward: {episode_reward}")
# Out:
# Max steps exceeded.
# Episode: 0, Reward: 5.958962511243845
# Max steps exceeded.
# Episode: 1, Reward: -8.012164225947151
# Max steps exceeded.
# Episode: 2, Reward: -10.998350211588619
# Max steps exceeded.
# Episode: 3, Reward: -16.104047198036465
# Max steps exceeded.
# Episode: 4, Reward: -17.490106783605025
# Max steps exceeded.
# Episode: 5, Reward: -9.121707154917056
# Max steps exceeded.
# Episode: 6, Reward: -4.842007468359885
# Max steps exceeded.
# Episode: 7, Reward: -6.028315415305465
# Max steps exceeded.
# Episode: 8, Reward: -10.42256926347196
# Max steps exceeded.
# Episode: 9, Reward: -7.916505128070455
# Max steps exceeded.
# Episode: 10, Reward: 4.513449038204132
# Max steps exceeded.
# Episode: 11, Reward: 0.44579202318341676
# Goal reached!
# Episode: 12, Reward: 112.04137999269321
# Max steps exceeded.
# Episode: 13, Reward: -3.6350544969118985
# Max steps exceeded.
# Episode: 14, Reward: -5.542932783602734
# Max steps exceeded.
# Episode: 15, Reward: 1.231143295171348
# Max steps exceeded.
# Episode: 16, Reward: -2.016902140958825
# Max steps exceeded.
# Episode: 17, Reward: -4.561342854576519
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 18, Reward: 9.466064252995592
# Max steps exceeded.
# Episode: 19, Reward: 3.1510303790158325
# Max steps exceeded.
# Episode: 20, Reward: 3.717873255687978
# Max steps exceeded.
# Episode: 21, Reward: -1.3674273654388474
# Max steps exceeded.
# Episode: 22, Reward: 3.024394672690418
# Max steps exceeded.
# Episode: 23, Reward: -8.923703124601676
# Max steps exceeded.
# Episode: 24, Reward: -1.4569418912340824
# Max steps exceeded.
# Episode: 25, Reward: 11.554459090689688
# Max steps exceeded.
# Episode: 26, Reward: -1.4378958251954026
# Max steps exceeded.
# Episode: 27, Reward: 7.198843207629439
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 28, Reward: 5.892870607706165
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 29, Reward: 11.852988694118006
# Max steps exceeded.
# Episode: 30, Reward: -3.1187045835949534
# Max steps exceeded.
# Episode: 31, Reward: -2.2383577427619494
# Max steps exceeded.
# Episode: 32, Reward: -7.1772318539300635
# Max steps exceeded.
# Episode: 33, Reward: -8.322706034853791
# Max steps exceeded.
# Episode: 34, Reward: -10.777536842010456
# Max steps exceeded.
# Episode: 35, Reward: -5.203079796515301
# Max steps exceeded.
# Episode: 36, Reward: -7.958651828069739
# Max steps exceeded.
# Episode: 37, Reward: -6.307083870764528
# Max steps exceeded.
# Episode: 38, Reward: -7.712603615929561
# Max steps exceeded.
# Episode: 39, Reward: -11.729868342523266
# Max steps exceeded.
# Episode: 40, Reward: -20.394556231311874
# Max steps exceeded.
# Episode: 41, Reward: -18.999448774419907
# Max steps exceeded.
# Episode: 42, Reward: -7.217363522992865
# Max steps exceeded.
# Episode: 43, Reward: -12.868811555478139
# Max steps exceeded.
# Episode: 44, Reward: -13.373200424433199
# Max steps exceeded.
# Episode: 45, Reward: -14.598180416574019
# Max steps exceeded.
# Episode: 46, Reward: -17.20832889720888
# Max steps exceeded.
# Episode: 47, Reward: -16.135402152806577
# Max steps exceeded.
# Episode: 48, Reward: -10.07660090664255
# Max steps exceeded.
# Episode: 49, Reward: -15.444676421621967
# Max steps exceeded.
# Episode: 50, Reward: -2.0036407467121378
# Max steps exceeded.
# Episode: 51, Reward: -2.8580771593068093
# Max steps exceeded.
# Episode: 52, Reward: -11.198236385343797
# Max steps exceeded.
# Episode: 53, Reward: -2.9755012922780755
# Max steps exceeded.
# Episode: 54, Reward: -0.560355532132062
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 55, Reward: 6.342220569690681
# Max steps exceeded.
# Episode: 56, Reward: -4.939624416725248
# Max steps exceeded.
# Episode: 57, Reward: -0.44037133384323435
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 58, Reward: 1.827022424845045
# Max steps exceeded.
# Episode: 59, Reward: -16.94527281359909
# Max steps exceeded.
# Episode: 60, Reward: -10.190748920575704
# Max steps exceeded.
# Episode: 61, Reward: -11.147480970018918
# Max steps exceeded.
# Episode: 62, Reward: -10.661190657258473
# Max steps exceeded.
# Episode: 63, Reward: -10.302972544588792
# Max steps exceeded.
# Episode: 64, Reward: -11.572859665799784
# Max steps exceeded.
# Episode: 65, Reward: -8.918576603022771
# Max steps exceeded.
# Episode: 66, Reward: -11.836956827664174
# Max steps exceeded.
# Episode: 67, Reward: -10.96283984264824
# Episode: 68, Reward: -96.22050799003982
# Max steps exceeded.
# Episode: 69, Reward: -13.50129434312507
# Max steps exceeded.
# Episode: 70, Reward: -11.863034741814877
# Max steps exceeded.
# Episode: 71, Reward: -9.999228883435118
# Max steps exceeded.
# Episode: 72, Reward: -11.127587765706727
# Max steps exceeded.
# Episode: 73, Reward: -11.072726819074948
# Max steps exceeded.
# Episode: 74, Reward: -10.958700634459625
# Max steps exceeded.
# Episode: 75, Reward: -11.675094937456743
# Max steps exceeded.
# Episode: 76, Reward: -9.923226909089145
# Max steps exceeded.
# Episode: 77, Reward: -11.269687068258008
# Max steps exceeded.
# Episode: 78, Reward: -1.1427808662113863
# Max steps exceeded.
# Episode: 79, Reward: -10.90224982059755
# Max steps exceeded.
# Episode: 80, Reward: -9.892379386885517
# Max steps exceeded.
# Episode: 81, Reward: -11.063017415225803
# Max steps exceeded.
# Episode: 82, Reward: -10.040238796602766
# Max steps exceeded.
# Episode: 83, Reward: -11.49797414839672
# Max steps exceeded.
# Episode: 84, Reward: -11.848361303677201
# Max steps exceeded.
# Episode: 85, Reward: -11.560047200662982
# Max steps exceeded.
# Episode: 86, Reward: -12.530320043926853
# Max steps exceeded.
# Episode: 87, Reward: -11.2351487025173
# Max steps exceeded.
# Episode: 88, Reward: -13.565661259443273
# Max steps exceeded.
# Episode: 89, Reward: -11.802805944131435
# Max steps exceeded.
# Episode: 90, Reward: -8.144484936734829
# Max steps exceeded.
# Episode: 91, Reward: -9.745695749843303
# Max steps exceeded.
# Episode: 92, Reward: 1.5741927281380006
# Max steps exceeded.
# Episode: 93, Reward: -10.37715697471974
# Max steps exceeded.
# Episode: 94, Reward: -6.023278709733817
# Max steps exceeded.
# Episode: 95, Reward: -11.090969733732061
# Max steps exceeded.
# Episode: 96, Reward: -10.32209713437443
# Episode: 97, Reward: -96.13391491545768
# Max steps exceeded.
# Episode: 98, Reward: -11.298320374995916
# Max steps exceeded.
# Episode: 99, Reward: -10.639833680863184
# Max steps exceeded.
# Episode: 100, Reward: -9.22433395253358
# Max steps exceeded.
# Episode: 101, Reward: -2.2902402544889835
# Max steps exceeded.
# Episode: 102, Reward: 1.181494914807116
# Max steps exceeded.
# Episode: 103, Reward: -11.609751833855261
# Max steps exceeded.
# Episode: 104, Reward: -6.144013999578646
# Max steps exceeded.
# Episode: 105, Reward: 0.9699269221566609
# Max steps exceeded.
# Episode: 106, Reward: -4.4338046639104665
# Max steps exceeded.
# Episode: 107, Reward: -9.839110108668834
# Max steps exceeded.
# Episode: 108, Reward: -11.220033298032634
# Max steps exceeded.
# Episode: 109, Reward: -12.462989303099619
# Max steps exceeded.
# Episode: 110, Reward: -11.54755004738798
# Max steps exceeded.
# Episode: 111, Reward: -10.039295794214812
# Max steps exceeded.
# Episode: 112, Reward: -12.05164644634877
# Max steps exceeded.
# Episode: 113, Reward: -10.934769054875687
# Max steps exceeded.
# Episode: 114, Reward: -10.146098546736201
# Max steps exceeded.
# Episode: 115, Reward: -11.656092273129191
# Max steps exceeded.
# Episode: 116, Reward: -12.533598865648413
# Max steps exceeded.
# Episode: 117, Reward: -8.335087948983926
# Max steps exceeded.
# Episode: 118, Reward: -6.20320755241829
# Max steps exceeded.
# Episode: 119, Reward: -11.167542513592688
# Max steps exceeded.
# Episode: 120, Reward: -10.961074347158613
# Max steps exceeded.
# Episode: 121, Reward: -11.508678730778612
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 122, Reward: 4.5841495061024
# Max steps exceeded.
# Episode: 123, Reward: -9.726574572964473
# Max steps exceeded.
# Episode: 124, Reward: -10.296888863043428
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 125, Reward: 3.4969802161891694
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 126, Reward: 3.3132065540242577
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 127, Reward: 3.528980170300666
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 128, Reward: 3.3132065540242577
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 129, Reward: 3.5722591758058093
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 130, Reward: 3.1856270110656206
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 131, Reward: 3.906304335628649
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 132, Reward: 3.3655543091604594
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 133, Reward: 3.254750483722926
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 134, Reward: 3.3132065540242577
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 135, Reward: 3.268636625721076
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 136, Reward: 3.3132065540242577
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 137, Reward: 3.2078218990548804
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 138, Reward: 3.1518113157403618
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 139, Reward: 3.1953000472515014
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 140, Reward: 3.1167366828896066
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 141, Reward: 3.2177232391939694
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 142, Reward: 3.2213625051182557
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 143, Reward: 3.1847633004241533
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 144, Reward: 3.0585820999889273
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 145, Reward: 3.071346810955238
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 146, Reward: 3.065324754994152
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 147, Reward: 3.0710617889050598
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 148, Reward: 2.896678307903995
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 149, Reward: 2.7383760991083337
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 150, Reward: 2.4146243013521937
# Max steps exceeded.
# Episode: 151, Reward: -8.8473627588526
# Max steps exceeded.
# Episode: 152, Reward: -12.808011799515887
# Max steps exceeded.
# Episode: 153, Reward: -13.112001362058107
# Max steps exceeded.
# Episode: 154, Reward: -12.086338671427196
# Max steps exceeded.
# Episode: 155, Reward: -18.32650771204094
# Max steps exceeded.
# Episode: 156, Reward: -13.703720443081778
# Max steps exceeded.
# Episode: 157, Reward: -12.928314492916929
# Max steps exceeded.
# Episode: 158, Reward: -13.25306416748423
# Max steps exceeded.
# Episode: 159, Reward: -16.35312037268268
# Max steps exceeded.
# Episode: 160, Reward: -12.293219284097928
# Max steps exceeded.
# Episode: 161, Reward: -15.09444886310702
# Max steps exceeded.
# Episode: 162, Reward: -19.80428550205537
# Max steps exceeded.
# Episode: 163, Reward: -11.065994015789542
# Max steps exceeded.
# Episode: 164, Reward: -16.950081090436598
# Max steps exceeded.
# Episode: 165, Reward: -20.234357851828474
# Max steps exceeded.
# Episode: 166, Reward: -18.54867461400896
# Max steps exceeded.
# Episode: 167, Reward: -13.571918451382766
# Max steps exceeded.
# Episode: 168, Reward: -16.607806041148194
# Max steps exceeded.
# Episode: 169, Reward: -19.03432768594062
# Max steps exceeded.
# Episode: 170, Reward: -15.920993203672893
# Max steps exceeded.
# Episode: 171, Reward: 3.9120816973591026
# Episode: 172, Reward: -95.10479455449708
# Max steps exceeded.
# Episode: 173, Reward: -11.453302828453669
# Max steps exceeded.
# Episode: 174, Reward: -15.383303548833599
# Max steps exceeded.
# Episode: 175, Reward: -13.846513235249322
# Max steps exceeded.
# Episode: 176, Reward: -2.5204777438016723
# Max steps exceeded.
# Episode: 177, Reward: -13.999278787787938
# Max steps exceeded.
# Episode: 178, Reward: -19.767285953388527
# Max steps exceeded.
# Episode: 179, Reward: -15.13338225110107
# Max steps exceeded.
# Episode: 180, Reward: 1.676290570010515
# Goal reached!
# Episode: 181, Reward: 115.32159978385289
# Max steps exceeded.
# Episode: 182, Reward: -16.547683049232848
# Max steps exceeded.
# Episode: 183, Reward: 0.9856230065109832
# Max steps exceeded.
# Episode: 184, Reward: -18.511935806307346
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 185, Reward: 5.769693137693122
# Max steps exceeded.
# Episode: 186, Reward: -16.417064836566986
# Max steps exceeded.
# Episode: 187, Reward: -14.733834345708084
# Max steps exceeded.
# Episode: 188, Reward: -18.949640169895165
# Max steps exceeded.
# Episode: 189, Reward: -17.44104607624588
# Max steps exceeded.
# Episode: 190, Reward: -18.434273156571685
# Max steps exceeded.
# Episode: 191, Reward: -20.31482079818715
# Max steps exceeded.
# Episode: 192, Reward: -10.69074582751857
# Max steps exceeded.
# Episode: 193, Reward: -9.64675226118759
# Max steps exceeded.
# Episode: 194, Reward: -10.292445634591253
# Max steps exceeded.
# Episode: 195, Reward: -14.98359844086734
# Max steps exceeded.
# Episode: 196, Reward: -16.40522728737448
# Max steps exceeded.
# Episode: 197, Reward: -7.867573452390783
# Max steps exceeded.
# Episode: 198, Reward: -13.94981731272402
# Max steps exceeded.
# Episode: 199, Reward: -14.064255439226523
# Max steps exceeded.
# Episode: 200, Reward: -15.896485220531858
# Max steps exceeded.
# Episode: 201, Reward: -15.3458997922614
# Max steps exceeded.
# Episode: 202, Reward: -13.138940989882256
# Max steps exceeded.
# Episode: 203, Reward: -13.546283507392735
# Max steps exceeded.
# Episode: 204, Reward: -14.557948988667095
# Max steps exceeded.
# Episode: 254, Reward: -10.914364795634983
# Max steps exceeded.
# Episode: 255, Reward: -12.017853695387918
# Max steps exceeded.
# Episode: 256, Reward: -11.83049525850148
# Max steps exceeded.
# Episode: 257, Reward: -16.080534070851858
# Max steps exceeded.
# Episode: 258, Reward: -19.71561027185056
# Max steps exceeded.
# Episode: 259, Reward: -20.05261410997992
# Max steps exceeded.
# Episode: 260, Reward: -13.611142156678214
# Max steps exceeded.
# Episode: 261, Reward: -19.15680203941166
# Max steps exceeded.
# Episode: 262, Reward: -18.845567111295257
# Max steps exceeded.
# Episode: 263, Reward: -16.018550698688898
# Max steps exceeded.
# Episode: 264, Reward: -18.801223339146304
# Max steps exceeded.
# Episode: 265, Reward: -20.692103573638157
# Max steps exceeded.
# Episode: 266, Reward: -18.528117456669975
# Max steps exceeded.
# Episode: 267, Reward: -14.241070271066286
# Max steps exceeded.
# Episode: 268, Reward: -11.557078599228456
# Max steps exceeded.
# Episode: 269, Reward: -8.99149667748324
# Max steps exceeded.
# Episode: 270, Reward: -17.415065234195147
# Max steps exceeded.
# Episode: 271, Reward: -14.825078972168564
# Max steps exceeded.
# Episode: 272, Reward: -13.745623337915259
# Max steps exceeded.
# Episode: 273, Reward: -13.393536249337762
# Max steps exceeded.
# Episode: 274, Reward: -13.41573092519958
# Max steps exceeded.
# Episode: 275, Reward: -19.581614424170954
# Max steps exceeded.
# Episode: 276, Reward: -13.315576444484162
# Max steps exceeded.
# Episode: 277, Reward: -11.400988497311314
# Max steps exceeded.
# Episode: 278, Reward: -19.699967600443497
# Max steps exceeded.
# Episode: 279, Reward: -10.142894311513212
# Max steps exceeded.
# Episode: 280, Reward: -17.110319656189038
# Max steps exceeded.
# Episode: 281, Reward: -14.188012043236617
# Max steps exceeded.
# Episode: 282, Reward: -9.995953875598868
# Max steps exceeded.
# Episode: 283, Reward: -11.035912585820325
# Max steps exceeded.
# Episode: 284, Reward: -12.184838389783412
# Max steps exceeded.
# Episode: 285, Reward: -13.54130558327869
# Max steps exceeded.
# Episode: 286, Reward: -15.102161418261296
# Max steps exceeded.
# Episode: 287, Reward: -13.19804698740132
# Max steps exceeded.
# Episode: 288, Reward: -17.027406526976115
# Max steps exceeded.
# Episode: 289, Reward: -15.828309087897736
# Max steps exceeded.
# Episode: 290, Reward: -15.155673517307068
# Max steps exceeded.
# Episode: 291, Reward: -20.499944921366104
# Max steps exceeded.
# Episode: 292, Reward: -5.483051879113802
# Max steps exceeded.
# Episode: 293, Reward: -18.027515545979274
# Max steps exceeded.
# Episode: 294, Reward: -10.581451183204774
# Max steps exceeded.
# Episode: 295, Reward: -14.64859776411686
# Max steps exceeded.
# Episode: 296, Reward: -8.978913951986355
# Max steps exceeded.
# Episode: 297, Reward: -9.476649407260638
# Max steps exceeded.
# Episode: 298, Reward: -4.578189112983821
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 299, Reward: -0.14603562079107976
# Max steps exceeded.
# Episode: 300, Reward: -3.015797369297483
# Max steps exceeded.
# Episode: 301, Reward: 2.1928924950012205
# Max steps exceeded.
# Episode: 302, Reward: -6.537419465240583
# Max steps exceeded.
# Episode: 303, Reward: -3.0041742597183543
# Max steps exceeded.
# Episode: 304, Reward: 1.4261592347369219
# Max steps exceeded.
# Episode: 305, Reward: -2.4517615086077615
# Max steps exceeded.
# Episode: 306, Reward: -1.4419293450311585
# Max steps exceeded.
# Episode: 307, Reward: -10.898094431684745
# Max steps exceeded.
# Episode: 308, Reward: -0.3977844610556607
# Max steps exceeded.
# Episode: 309, Reward: -2.2183665309687024
# Max steps exceeded.
# Episode: 310, Reward: -3.5493049028198733
# Max steps exceeded.
# Episode: 311, Reward: -1.933043634527434
# Max steps exceeded.
# Episode: 312, Reward: -0.7409305742560482
# Max steps exceeded.
# Episode: 313, Reward: -2.6476515941396546
# Max steps exceeded.
# Episode: 314, Reward: -2.3374778863755346
# Max steps exceeded.
# Episode: 315, Reward: -3.1984043595269456
# Max steps exceeded.
# Episode: 316, Reward: -4.000577321148044
# Max steps exceeded.
# Episode: 317, Reward: -4.5594442637216615
# Max steps exceeded.
# Episode: 318, Reward: 0.4688709790784535
# Max steps exceeded.
# Episode: 319, Reward: 0.8600303400722416
# Max steps exceeded.
# Episode: 320, Reward: -17.23478360935292
# Max steps exceeded.
# Episode: 321, Reward: -1.2305860190169688
# Max steps exceeded.
# Episode: 322, Reward: -0.6645579747286285
# Max steps exceeded.
# Episode: 323, Reward: -2.7209498751265166
# Max steps exceeded.
# Episode: 324, Reward: -4.955341205513214
# Max steps exceeded.
# Episode: 325, Reward: -1.1421236632145058
# Max steps exceeded.
# Episode: 326, Reward: -1.5105378044262974
# Max steps exceeded.
# Episode: 327, Reward: -3.130114502465022
# Max steps exceeded.
# Episode: 328, Reward: -5.9585713212763265
# Max steps exceeded.
# Episode: 329, Reward: -6.491410521402701
# Max steps exceeded.
# Episode: 330, Reward: -5.376972796289147
# Max steps exceeded.
# Episode: 331, Reward: -5.323625693655201
# Max steps exceeded.
# Episode: 332, Reward: -2.978022237578811
# Max steps exceeded.
# Episode: 333, Reward: -3.9791643286289915
# Max steps exceeded.
# Episode: 334, Reward: -10.750746589854106
# Max steps exceeded.
# Episode: 335, Reward: -4.368331589320163
# Max steps exceeded.
# Episode: 336, Reward: -4.991258456321907
# Max steps exceeded.
# Episode: 337, Reward: -5.098390842173595
# Max steps exceeded.
# Episode: 338, Reward: -3.3303543834878497
# Max steps exceeded.
# Episode: 339, Reward: -5.921998860426659
# Max steps exceeded.
# Episode: 340, Reward: -4.866894465629835
# Max steps exceeded.
# Episode: 341, Reward: -3.4255387811479383
# Max steps exceeded.
# Episode: 342, Reward: -4.739774796000469
# Max steps exceeded.
# Episode: 343, Reward: -5.795230574740109
# Max steps exceeded.
# Episode: 344, Reward: -3.8559331030272666
# Max steps exceeded.
# Episode: 345, Reward: 0.5919469134327059
# Max steps exceeded.
# Episode: 346, Reward: -1.6019350700557033
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 347, Reward: 1.8068686200479265
# Max steps exceeded.
# Episode: 348, Reward: -0.6731472832664582
# Max steps exceeded.
# Episode: 349, Reward: 0.09825044211955941
# Max steps exceeded.
# Episode: 350, Reward: 0.9002122319543411
# Max steps exceeded.
# Episode: 351, Reward: 0.010831886650100653
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 352, Reward: -0.7290412431022815
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 353, Reward: 3.1613555210473514
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 354, Reward: 3.0876581104426597
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 355, Reward: 1.815185327599832
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 356, Reward: 2.164212003010715
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 357, Reward: 4.979528970240764
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 358, Reward: 3.19641353801932
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 359, Reward: 3.5531281617951507
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 360, Reward: 3.0523506234352054
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 361, Reward: 0.45453040191300387
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 362, Reward: 3.157287680897228
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 363, Reward: 3.4331137825819864
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 364, Reward: 3.187034184022206
# Max steps exceeded.
# Episode: 365, Reward: 0.8486192358272934
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 366, Reward: 4.583862253179966
# Max steps exceeded.
# Episode: 367, Reward: 1.1032597572301854
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 368, Reward: 5.7107534907028965
# Max steps exceeded.
# Episode: 369, Reward: 0.4002986446728829
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 370, Reward: 3.4029765457405183
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 371, Reward: 3.1711169689501544
# Max steps exceeded.
# Episode: 372, Reward: -2.651600145900004
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 373, Reward: 2.3449222387239654
# Max steps exceeded.
# Episode: 374, Reward: -1.940452840534553
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 375, Reward: 2.5228350618591295
# Max steps exceeded.
# Episode: 376, Reward: -0.6414815715226988
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 377, Reward: 2.4099648588725144
# Max steps exceeded.
# Episode: 378, Reward: 0.7625448233726914
# Max steps exceeded.
# Episode: 379, Reward: -0.8203105912183586
# Max steps exceeded.
# Episode: 380, Reward: -3.0195587359050458
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 381, Reward: 2.491808825256533
# Max steps exceeded.
# Episode: 382, Reward: -1.5906745229760175
# Max steps exceeded.
# Episode: 383, Reward: -3.521748469858518
# Max steps exceeded.
# Episode: 384, Reward: -3.69201443567372
# Max steps exceeded.
# Episode: 385, Reward: -6.722020770220793
# Max steps exceeded.
# Episode: 386, Reward: -2.216676352636786
# Max steps exceeded.
# Episode: 387, Reward: -7.305907279197383
# Max steps exceeded.
# Episode: 388, Reward: -3.6124971341281302
# Max steps exceeded.
# Episode: 389, Reward: -2.049787091370405
# Max steps exceeded.
# Episode: 390, Reward: -12.671592427145256
# Max steps exceeded.
# Episode: 391, Reward: -3.981357167469598
# Max steps exceeded.
# Episode: 392, Reward: -8.40981306540144
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 393, Reward: 4.092800951745389
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 394, Reward: 6.228374276584421
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 395, Reward: 7.11878176317812
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 396, Reward: 12.274030573260566
# Episode: 397, Reward: -92.11856888439245
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 398, Reward: -10.916611973890245
# Max steps exceeded.
# Episode: 399, Reward: 2.383629857577916
# Max steps exceeded.
# Episode: 400, Reward: 3.140680685989695
# Goal reached!
# Episode: 401, Reward: 112.86695120335024
# Max steps exceeded.
# Episode: 402, Reward: -12.37378746574015
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 403, Reward: -12.078134554179258
# Max steps exceeded.
# Episode: 404, Reward: -10.273750848199805
# Max steps exceeded.
# Episode: 405, Reward: 0.7900557994461674
# Max steps exceeded.
# Episode: 406, Reward: -12.617881263938747
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 407, Reward: 0.08227401424628367
# Max steps exceeded.
# Episode: 408, Reward: 2.377006355935363
# Max steps exceeded.
# Episode: 409, Reward: 5.291236374322177
# Max steps exceeded.
# Episode: 410, Reward: -15.32439568661129
# Max steps exceeded.
# Episode: 411, Reward: -12.750424190012158
# Max steps exceeded.
# Episode: 412, Reward: -12.516315111583546
# Max steps exceeded.
# Episode: 413, Reward: -5.9478261004267905
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 414, Reward: 2.3534888659778908
# Max steps exceeded.
# Episode: 415, Reward: -10.919497844321027
# Max steps exceeded.
# Episode: 416, Reward: -9.005141041667297
# Max steps exceeded.
# Episode: 417, Reward: -11.97352023663829
# Max steps exceeded.
# Episode: 418, Reward: -11.029587902834487
# Max steps exceeded.
# Episode: 419, Reward: -11.24362084311801
# Max steps exceeded.
# Episode: 420, Reward: -15.436781953205712
# Max steps exceeded.
# Episode: 421, Reward: -15.277990762415982
# Max steps exceeded.
# Episode: 422, Reward: -14.40490207073599
# Max steps exceeded.
# Episode: 423, Reward: -11.341167212239288
# Max steps exceeded.
# Episode: 424, Reward: -10.584820796592425
# Max steps exceeded.
# Episode: 425, Reward: -11.882358655260987
# Max steps exceeded.
# Episode: 426, Reward: -13.958448751109128
# Max steps exceeded.
# Episode: 427, Reward: -11.106954269274041
# Max steps exceeded.
# Episode: 428, Reward: -10.444091491614083
# Max steps exceeded.
# Episode: 429, Reward: -11.727339976459088
# Max steps exceeded.
# Episode: 430, Reward: -12.933760189959074
# Max steps exceeded.
# Episode: 431, Reward: -11.167942948589253
# Max steps exceeded.
# Episode: 432, Reward: -16.420075184233195
# Max steps exceeded.
# Episode: 433, Reward: -16.26473534330869
# Max steps exceeded.
# Episode: 434, Reward: -13.474430415317537
# Max steps exceeded.
# Episode: 435, Reward: -16.05329869944944
# Max steps exceeded.
# Episode: 436, Reward: -19.058955284642177
# Max steps exceeded.
# Episode: 437, Reward: -13.490429318528617
# Max steps exceeded.
# Episode: 438, Reward: -19.024264038196566
# Max steps exceeded.
# Episode: 439, Reward: -13.146315327224892
# Max steps exceeded.
# Episode: 440, Reward: -13.87810364035998
# Max steps exceeded.
# Episode: 441, Reward: -18.5793365010361
# Max steps exceeded.
# Episode: 442, Reward: -19.473230166372897
# Max steps exceeded.
# Episode: 443, Reward: -19.365129437920324
# Max steps exceeded.
# Episode: 444, Reward: -19.318887978017205
# Max steps exceeded.
# Episode: 445, Reward: -18.691946638005103
# Max steps exceeded.
# Episode: 446, Reward: -17.85472753609989
# Max steps exceeded.
# Episode: 447, Reward: -18.284393678750778
# Max steps exceeded.
# Episode: 448, Reward: -18.707719558644577
# Max steps exceeded.
# Episode: 449, Reward: -11.433088496428661
# Max steps exceeded.
# Episode: 450, Reward: -18.459724169572368
# Max steps exceeded.
# Episode: 451, Reward: -13.317985427067974
# Max steps exceeded.
# Episode: 452, Reward: -11.6704655972731
# Max steps exceeded.
# Episode: 453, Reward: -18.74131217840757
# Max steps exceeded.
# Episode: 454, Reward: -12.284331056987947
# Max steps exceeded.
# Episode: 455, Reward: -11.828322929932671
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 456, Reward: 2.8455197445091125
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 457, Reward: 2.926728530732856
# Max steps exceeded.
# Episode: 458, Reward: -10.43328703188924
# Max steps exceeded.
# Episode: 459, Reward: -8.106330444576285
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 460, Reward: 2.8055775561829357
# Max steps exceeded.
# Episode: 461, Reward: -10.110067791762768
# Max steps exceeded.
# Episode: 462, Reward: -15.19853678874619
# Max steps exceeded.
# Episode: 463, Reward: -12.341485209298876
# Max steps exceeded.
# Episode: 464, Reward: -12.40991707190133
# Max steps exceeded.
# Episode: 465, Reward: -7.238788256383945
# Max steps exceeded.
# Episode: 466, Reward: -10.25529239158436
# Max steps exceeded.
# Episode: 467, Reward: -10.751265054167986
# Max steps exceeded.
# Episode: 468, Reward: -1.7727303705830517
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 469, Reward: 0.12796354261023368
# Max steps exceeded.
# Episode: 470, Reward: -6.586646954136989
# Max steps exceeded.
# Episode: 471, Reward: -4.108009295810101
# Max steps exceeded.
# Episode: 472, Reward: 3.4131541681749877
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 473, Reward: 2.682895516626272
# Max steps exceeded.
# Episode: 474, Reward: -4.731155817091115
# Max steps exceeded.
# Episode: 475, Reward: -8.04441085809035
# Max steps exceeded.
# Episode: 476, Reward: 0.5641610763503285
# Max steps exceeded.
# Episode: 477, Reward: 1.9737302170368571
# Max steps exceeded.
# Episode: 478, Reward: -1.830379987274882
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 479, Reward: 1.9001576584544697
# Max steps exceeded.
# Episode: 480, Reward: -5.701602070149174
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 481, Reward: 1.4804883866716907
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 482, Reward: 1.749155866128371
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 483, Reward: 1.6342480295718365
# Max steps exceeded.
# Episode: 484, Reward: 1.0817741847426658
# Max steps exceeded.
# Episode: 485, Reward: -2.5296421013234145
# Max steps exceeded.
# Episode: 486, Reward: -8.075451682220303
# Max steps exceeded.
# Episode: 487, Reward: -10.387498711193247
# Max steps exceeded.
# Episode: 488, Reward: -9.43399496475477
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 489, Reward: 1.885756068944365
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 490, Reward: -8.741196232094298
# Collision detected! Taking avoidance measures.
# Episode: 491, Reward: -95.79553261756509
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 492, Reward: 3.2519539387046743
# Max steps exceeded.
# Episode: 493, Reward: -7.3549213922205725
# Max steps exceeded.
# Episode: 494, Reward: -10.368673753909178
# Max steps exceeded.
# Episode: 495, Reward: 11.955718743491886
# Max steps exceeded.
# Episode: 496, Reward: 1.1280000103329026
# Max steps exceeded.
# Episode: 497, Reward: -10.327401278285345
# Max steps exceeded.
# Episode: 498, Reward: -10.421904198278426
# Max steps exceeded.
# Episode: 499, Reward: -10.079274243980922
# Max steps exceeded.
# Episode: 500, Reward: -17.825155940789543
# Max steps exceeded.
# Episode: 501, Reward: 1.8105732318641627
# Max steps exceeded.
# Episode: 502, Reward: -7.17672816311566
# Max steps exceeded.
# Episode: 503, Reward: -7.496870312639273
# Max steps exceeded.
# Episode: 504, Reward: -8.91312220226468
# Max steps exceeded.
# Episode: 505, Reward: 1.6787320923733546
# Max steps exceeded.
# Episode: 506, Reward: -3.884251214993626
# Max steps exceeded.
# Episode: 507, Reward: -5.692640984929414
# Max steps exceeded.
# Episode: 508, Reward: -9.353114878930533
# Max steps exceeded.
# Episode: 509, Reward: -10.890184136758503
# Max steps exceeded.
# Episode: 510, Reward: -10.700916053802867
# Max steps exceeded.
# Episode: 511, Reward: -0.45819395037809985
# Max steps exceeded.
# Episode: 512, Reward: -11.350379178959471
# Max steps exceeded.
# Episode: 513, Reward: -10.511511061960306
# Max steps exceeded.
# Episode: 514, Reward: -5.467985332015297
# Max steps exceeded.
# Episode: 515, Reward: -5.759172928277559
# Max steps exceeded.
# Episode: 516, Reward: -9.05753064155068
# Max steps exceeded.
# Episode: 517, Reward: -6.977019032183449
# Max steps exceeded.
# Episode: 518, Reward: -13.809300524243582
# Max steps exceeded.
# Episode: 519, Reward: -6.058611915973916
# Max steps exceeded.
# Episode: 520, Reward: -4.231759394180396
# Max steps exceeded.
# Episode: 521, Reward: 0.594353516492827
# Max steps exceeded.
# Episode: 522, Reward: -13.169318054322702
# Max steps exceeded.
# Episode: 523, Reward: -6.7558812419354135
# Max steps exceeded.
# Episode: 524, Reward: -9.092999765464391
# Max steps exceeded.
# Episode: 525, Reward: -10.134746733609093
# Max steps exceeded.
# Episode: 526, Reward: -6.830265196710769
# Max steps exceeded.
# Episode: 527, Reward: -8.36061571079316
# Episode: 528, Reward: -98.13879528911448
# Max steps exceeded.
# Episode: 529, Reward: 0.797689498275152
# Max steps exceeded.
# Episode: 530, Reward: -1.1559024964584477
# Max steps exceeded.
# Episode: 531, Reward: -10.916112164004613
# Max steps exceeded.
# Episode: 532, Reward: -2.681012564133205
# Max steps exceeded.
# Episode: 533, Reward: -8.593086784056199
# Max steps exceeded.
# Episode: 534, Reward: -7.232092252279587
# Max steps exceeded.
# Episode: 535, Reward: -8.517862668058733
# Max steps exceeded.
# Episode: 536, Reward: -7.8651618675703645
# Max steps exceeded.
# Episode: 537, Reward: -9.656351162924564
# Max steps exceeded.
# Episode: 538, Reward: -10.4774205506595
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 539, Reward: 3.1032443199035584
# Max steps exceeded.
# Episode: 540, Reward: -6.120554028281686
# Max steps exceeded.
# Episode: 541, Reward: -4.288716293876314
# Max steps exceeded.
# Episode: 542, Reward: -6.785110465353864
# Max steps exceeded.
# Episode: 543, Reward: -3.72286022646151
# Max steps exceeded.
# Episode: 544, Reward: -7.181613149280018
# Max steps exceeded.
# Episode: 545, Reward: -12.54716552621244
# Max steps exceeded.
# Episode: 546, Reward: -8.114518748829864
# Max steps exceeded.
# Episode: 547, Reward: -6.049939886146761
# Max steps exceeded.
# Episode: 548, Reward: 0.7139053216052849
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 549, Reward: 1.061261961184833
# Max steps exceeded.
# Episode: 550, Reward: -4.786138381515244
# Max steps exceeded.
# Episode: 551, Reward: -0.3470694820252114
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 552, Reward: 3.1352912834580073
# Max steps exceeded.
# Episode: 553, Reward: -3.760109263432914
# Max steps exceeded.
# Episode: 554, Reward: 1.5598577812869199
# Max steps exceeded.
# Episode: 555, Reward: -2.88485716393756
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 556, Reward: 1.9670762845250032
# Max steps exceeded.
# Episode: 557, Reward: 1.462893455086935
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 558, Reward: 4.305959958279855
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 559, Reward: 3.2037801879359527
# Max steps exceeded.
# Episode: 560, Reward: -8.755127042516234
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 561, Reward: 7.455800126395911
# Episode: 562, Reward: -96.19184747363454
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 563, Reward: 1.7811474883088567
# Max steps exceeded.
# Episode: 564, Reward: 1.1334551723346116
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 565, Reward: 5.266578094063884
# Max steps exceeded.
# Episode: 566, Reward: -2.8672049479168003
# Max steps exceeded.
# Episode: 567, Reward: -0.4360425170501846
# Max steps exceeded.
# Episode: 568, Reward: -2.651296038750031
# Max steps exceeded.
# Episode: 569, Reward: 0.024592140359798995
# Max steps exceeded.
# Episode: 570, Reward: -4.24490585158144
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 571, Reward: -6.800377957105797
# Max steps exceeded.
# Episode: 572, Reward: -3.002812985593589
# Max steps exceeded.
# Episode: 573, Reward: 7.6035967873446575
# Max steps exceeded.
# Episode: 574, Reward: -9.121815790459756
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 575, Reward: 1.1744470895621055
# Max steps exceeded.
# Episode: 576, Reward: -0.4727923033077527
# Max steps exceeded.
# Episode: 577, Reward: 0.7850654773420731
# Max steps exceeded.
# Episode: 578, Reward: -1.937637679972815
# Max steps exceeded.
# Episode: 579, Reward: 0.08398291086602087
# Max steps exceeded.
# Episode: 580, Reward: -8.393743360373476
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 581, Reward: -1.5475487891759685
# Max steps exceeded.
# Episode: 582, Reward: -1.8701255549600675
# Max steps exceeded.
# Episode: 583, Reward: -7.6934497648284355
# Max steps exceeded.
# Episode: 584, Reward: -4.581984411860742
# Max steps exceeded.
# Episode: 585, Reward: 0.5794075791851204
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 586, Reward: 1.6081884839770095
# Max steps exceeded.
# Episode: 587, Reward: 2.891506253983671
# Max steps exceeded.
# Episode: 588, Reward: -1.097377641287091
# Max steps exceeded.
# Episode: 589, Reward: -1.1483211700978884
# Max steps exceeded.
# Episode: 590, Reward: -2.2277978470313857
# Max steps exceeded.
# Episode: 591, Reward: 1.1680739362458474
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 592, Reward: 1.4442981130593306
# Max steps exceeded.
# Episode: 593, Reward: -1.3338500183556155
# Max steps exceeded.
# Episode: 594, Reward: -0.18787270753925928
# Max steps exceeded.
# Episode: 595, Reward: -1.5283096968066403
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 596, Reward: 1.8112976560498897
# Max steps exceeded.
# Episode: 597, Reward: -0.4956067844463445
# Max steps exceeded.
# Episode: 598, Reward: -0.15995233416006083
# Max steps exceeded.
# Episode: 599, Reward: -4.641473677292384
# Max steps exceeded.
# Episode: 600, Reward: -1.2155047073349683
# Max steps exceeded.
# Episode: 601, Reward: 2.2873957022661284
# Max steps exceeded.
# Episode: 602, Reward: -9.19980618043894
# Max steps exceeded.
# Episode: 603, Reward: -4.097828782265929
# Max steps exceeded.
# Episode: 604, Reward: -9.768259646002862
# Max steps exceeded.
# Episode: 605, Reward: 1.2396840556987296
# Max steps exceeded.
# Episode: 606, Reward: 0.39344507852907895
# Max steps exceeded.
# Episode: 607, Reward: -10.005140082413957
# Max steps exceeded.
# Episode: 608, Reward: 2.9307393107477373
# Max steps exceeded.
# Episode: 609, Reward: -10.818058236426806
# Max steps exceeded.
# Episode: 610, Reward: 0.22441208649398092
# Max steps exceeded.
# Episode: 611, Reward: -3.5071392516273807
# Max steps exceeded.
# Episode: 612, Reward: -2.2675414001694842
# Max steps exceeded.
# Episode: 613, Reward: -8.84326853038026
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 614, Reward: 3.390575140271202
# Max steps exceeded.
# Episode: 615, Reward: 2.2488379618605294
# Max steps exceeded.
# Episode: 616, Reward: 3.0043683836585062
# Max steps exceeded.
# Episode: 617, Reward: -6.256929380693832
# Max steps exceeded.
# Episode: 618, Reward: -8.857217426116781
# Max steps exceeded.
# Episode: 619, Reward: -21.853121053885204
# Max steps exceeded.
# Episode: 620, Reward: -22.76715073441844
# Max steps exceeded.
# Episode: 621, Reward: -9.42707479054765
# Max steps exceeded.
# Episode: 622, Reward: -4.220859134956913
# Max steps exceeded.
# Episode: 623, Reward: 1.5666301192477292
# Max steps exceeded.
# Episode: 624, Reward: -1.984916405748503
# Goal reached!
# Episode: 625, Reward: 113.3892423245477
# Goal reached!
# Episode: 626, Reward: 112.91199599448004
# Max steps exceeded.
# Episode: 627, Reward: -0.8125697484398057
# Max steps exceeded.
# Episode: 628, Reward: -2.721429344281569
# Max steps exceeded.
# Episode: 629, Reward: -19.22367697230356
# Max steps exceeded.
# Episode: 630, Reward: -19.4441481922344
# Max steps exceeded.
# Episode: 631, Reward: -16.59220312103585
# Max steps exceeded.
# Episode: 632, Reward: -9.27818959789322
# Max steps exceeded.
# Episode: 633, Reward: -16.698481056710026
# Max steps exceeded.
# Episode: 634, Reward: -17.367846462976942
# Max steps exceeded.
# Episode: 635, Reward: -10.821749169205999
# Max steps exceeded.
# Episode: 636, Reward: -21.22599591963209
# Max steps exceeded.
# Episode: 637, Reward: -16.456144676054063
# Max steps exceeded.
# Episode: 638, Reward: -18.410936449296464
# Max steps exceeded.
# Episode: 639, Reward: -15.835852244419408
# Max steps exceeded.
# Episode: 640, Reward: -12.053701912318642
# Max steps exceeded.
# Episode: 641, Reward: -11.05895774669076
# Max steps exceeded.
# Episode: 642, Reward: -18.402135184169257
# Max steps exceeded.
# Episode: 643, Reward: -6.793602727664708
# Max steps exceeded.
# Episode: 644, Reward: -15.64389083762676
# Max steps exceeded.
# Episode: 645, Reward: -15.367433160936898
# Max steps exceeded.
# Episode: 646, Reward: -2.8763719977101645
# Max steps exceeded.
# Episode: 647, Reward: -14.608994630984695
# Max steps exceeded.
# Episode: 648, Reward: -10.50657652397346
# Max steps exceeded.
# Episode: 649, Reward: 1.074211374192038
# Max steps exceeded.
# Episode: 650, Reward: -5.833000149376409
# Max steps exceeded.
# Episode: 651, Reward: 1.8467034603331174
# Max steps exceeded.
# Episode: 652, Reward: -5.7041478931789955
# Max steps exceeded.
# Episode: 653, Reward: -16.29842470806232
# Max steps exceeded.
# Episode: 654, Reward: -9.992106973982045
# Max steps exceeded.
# Episode: 655, Reward: -8.19021271761373
# Max steps exceeded.
# Episode: 656, Reward: -8.906325775489373
# Max steps exceeded.
# Episode: 657, Reward: -17.943015265169617
# Max steps exceeded.
# Episode: 658, Reward: -7.800662277612483
# Max steps exceeded.
# Episode: 659, Reward: -8.856358141936486
# Max steps exceeded.
# Episode: 660, Reward: -7.788079046597809
# Max steps exceeded.
# Episode: 661, Reward: -6.122383280967558
# Max steps exceeded.
# Episode: 662, Reward: -4.239408079766628
# Max steps exceeded.
# Episode: 663, Reward: -5.769129979240885
# Max steps exceeded.
# Episode: 664, Reward: -1.2887538062816948
# Max steps exceeded.
# Episode: 665, Reward: -4.254672040748342
# Max steps exceeded.
# Episode: 666, Reward: -5.468415551731581
# Max steps exceeded.
# ...
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 761, Reward: 0.35589841455687166
# Max steps exceeded.
# Episode: 762, Reward: -10.475099616784835
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 763, Reward: -1.092926908604531
# Max steps exceeded.
# Episode: 764, Reward: -0.7095444402097562
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 765, Reward: 0.7356759974550655
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 766, Reward: 2.7311956764684786
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 767, Reward: 2.1299512860094016
# Max steps exceeded.
# Episode: 768, Reward: 2.328654270174922
# Max steps exceeded.
# Episode: 769, Reward: -10.55452398636516
# Max steps exceeded.
# Episode: 770, Reward: -7.6498473649503875
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 771, Reward: 6.029124598019703
# Max steps exceeded.
# Episode: 772, Reward: -10.962631542517206
# Max steps exceeded.
# Episode: 773, Reward: -10.657544070126923
# Max steps exceeded.
# Episode: 774, Reward: -8.31854592395835
# Max steps exceeded.
# Episode: 775, Reward: -11.280092604385644
# Max steps exceeded.
# Episode: 776, Reward: -11.149106024238012
# Max steps exceeded.
# Episode: 777, Reward: -12.354701554539755
# Max steps exceeded.
# Episode: 778, Reward: -10.699601588605217
# Max steps exceeded.
# Episode: 779, Reward: -10.618821590208933
# Max steps exceeded.
# Episode: 780, Reward: 8.02980441044986
# Max steps exceeded.
# Episode: 781, Reward: -10.946695468480325
# Max steps exceeded.
# Episode: 782, Reward: -13.435081682679735
# Max steps exceeded.
# Episode: 783, Reward: -13.388660812214884
# Max steps exceeded.
# Episode: 784, Reward: -1.591298432329353
# Max steps exceeded.
# Episode: 785, Reward: -7.249315681465816
# Max steps exceeded.
# Episode: 786, Reward: -2.1446582546590545
# Max steps exceeded.
# Episode: 787, Reward: -7.1558274839280465
# Max steps exceeded.
# Episode: 788, Reward: -9.506777100824879
# Max steps exceeded.
# Episode: 789, Reward: -4.123582345538365
# Max steps exceeded.
# Episode: 790, Reward: 2.428898483920346
# Max steps exceeded.
# Episode: 791, Reward: 3.0849988804777753
# Max steps exceeded.
# Episode: 792, Reward: 2.2038009695323786
# Max steps exceeded.
# Episode: 793, Reward: -12.262237456591876
# Max steps exceeded.
# Episode: 794, Reward: -8.080563404819024
# Max steps exceeded.
# Episode: 795, Reward: 2.8589950299628084
# Max steps exceeded.
# Episode: 796, Reward: -6.280453720730624
# Max steps exceeded.
# Episode: 797, Reward: 2.4951562670771525
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 798, Reward: 6.159222237427994
# Max steps exceeded.
# Episode: 799, Reward: -9.351318329881197
# Max steps exceeded.
# Episode: 800, Reward: -9.479644840069012
# Max steps exceeded.
# Episode: 801, Reward: -8.580500408494817
# Max steps exceeded.
# Episode: 802, Reward: -3.673862791658727
# Max steps exceeded.
# Episode: 803, Reward: -4.01900972634345
# Max steps exceeded.
# Episode: 804, Reward: 2.3944289517111836
# Max steps exceeded.
# Episode: 805, Reward: 3.955024135224703
# Max steps exceeded.
# Episode: 806, Reward: -2.597513698609866
# Max steps exceeded.
# Episode: 807, Reward: 1.4468466583172495
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 808, Reward: 5.906959362342406
# Max steps exceeded.
# Episode: 809, Reward: -2.2707537660642534
# Max steps exceeded.
# Episode: 810, Reward: -7.44314050884743
# Max steps exceeded.
# Episode: 811, Reward: -5.266626789955301
# Max steps exceeded.
# Episode: 812, Reward: 7.866905293793877
# Max steps exceeded.
# Episode: 813, Reward: -9.357750412939744
# Max steps exceeded.
# Episode: 814, Reward: -9.870428863727513
# Max steps exceeded.
# Episode: 815, Reward: -10.177922643063829
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 816, Reward: 4.2685332091417925
# Max steps exceeded.
# Episode: 817, Reward: 3.0465647460187757
# Max steps exceeded.
# Episode: 818, Reward: -11.672906993167233
# Max steps exceeded.
# Episode: 819, Reward: 0.8883568332282561
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 820, Reward: 3.9275898024017244
# Max steps exceeded.
# Episode: 821, Reward: 3.3023837129437967
# Max steps exceeded.
# Episode: 822, Reward: 1.7353041409756544
# Max steps exceeded.
# Episode: 823, Reward: 1.6526741291347504
# Max steps exceeded.
# Episode: 824, Reward: 2.40538078296361
# Max steps exceeded.
# Episode: 825, Reward: 2.8596068005513318
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 826, Reward: 1.9012874266563404
# Max steps exceeded.
# Episode: 827, Reward: 0.28087860863674297
# Max steps exceeded.
# Episode: 828, Reward: -11.25216067476085
# Max steps exceeded.
# Episode: 829, Reward: -17.963757194451826
# Max steps exceeded.
# Episode: 830, Reward: -17.873469012237603
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 831, Reward: 2.0556164699740718
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 832, Reward: -2.058927294407006
# Max steps exceeded.
# Episode: 833, Reward: -9.846540436660295
# Max steps exceeded.
# Episode: 834, Reward: -18.57916881709958
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 835, Reward: 0.46038523257277664
# Max steps exceeded.
# Episode: 836, Reward: -9.724057067958785
# Max steps exceeded.
# Episode: 837, Reward: -19.907069782236135
# Max steps exceeded.
# Episode: 838, Reward: -17.809857422699274
# Max steps exceeded.
# Episode: 839, Reward: -8.785767325130598
# Max steps exceeded.
# Episode: 840, Reward: 2.67095694615899
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 841, Reward: 0.26938890891990996
# Max steps exceeded.
# Episode: 842, Reward: -5.570289648518827
# Max steps exceeded.
# Episode: 843, Reward: -1.222262161622683
# Max steps exceeded.
# Episode: 844, Reward: -6.717786577160401
# Max steps exceeded.
# Episode: 845, Reward: -10.219722948079049
# Max steps exceeded.
# Episode: 846, Reward: -18.66362821254079
# Max steps exceeded.
# Episode: 847, Reward: 2.2279883621985657
# Max steps exceeded.
# Episode: 848, Reward: 2.611076649391932
# Max steps exceeded.
# Episode: 849, Reward: -16.36024309194818
# Max steps exceeded.
# Episode: 850, Reward: -12.4694768793449
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 851, Reward: 3.9788896434587433
# Max steps exceeded.
# Episode: 852, Reward: -13.496803797586866
# Max steps exceeded.
# Episode: 853, Reward: -8.68603458790881
# Max steps exceeded.
# Episode: 854, Reward: -8.909458068508389
# Max steps exceeded.
# Episode: 855, Reward: -16.840036728881433
# Max steps exceeded.
# Episode: 856, Reward: -13.668459104271411
# Max steps exceeded.
# Episode: 857, Reward: -9.358876202991164
# Max steps exceeded.
# Episode: 858, Reward: -7.033725905156405
# Max steps exceeded.
# Episode: 859, Reward: -17.230005857356897
# Max steps exceeded.
# Episode: 860, Reward: -12.308514210284587
# Max steps exceeded.
# Episode: 861, Reward: -17.56733945285906
# Max steps exceeded.
# Episode: 862, Reward: -16.886227873814185
# Max steps exceeded.
# Episode: 863, Reward: -12.867701477948303
# Max steps exceeded.
# Episode: 864, Reward: -14.330101429524444
# Max steps exceeded.
# Episode: 865, Reward: 2.2719916030847935
# Max steps exceeded.
# Episode: 866, Reward: 2.536312570174518
# Max steps exceeded.
# Episode: 867, Reward: 1.8665967765503777
# Max steps exceeded.
# Episode: 868, Reward: -16.943055211648126
# Max steps exceeded.
# Episode: 869, Reward: 2.2814521140853365
# Max steps exceeded.
# Episode: 870, Reward: -8.876155857017254
# Max steps exceeded.
# Episode: 871, Reward: -17.618925923481555
# Max steps exceeded.
# Episode: 872, Reward: 2.8776831589405267
# Max steps exceeded.
# Episode: 873, Reward: 0.6324101141329806
# Max steps exceeded.
# Episode: 874, Reward: 2.8605816754126705
# Max steps exceeded.
# Episode: 875, Reward: -15.833118719487619
# Max steps exceeded.
# Episode: 876, Reward: 3.6160032154624804
# Max steps exceeded.
# Episode: 877, Reward: 1.927851344505123
# Max steps exceeded.
# Episode: 878, Reward: 1.5535057627646764
# Max steps exceeded.
# Episode: 879, Reward: -11.06682817258791
# Max steps exceeded.
# Episode: 880, Reward: 0.7050393740016898
# Max steps exceeded.
# Episode: 881, Reward: 3.457114870475585
# Max steps exceeded.
# Episode: 882, Reward: -16.16373890347776
# Max steps exceeded.
# Episode: 883, Reward: -10.673375673060535
# Max steps exceeded.
# Episode: 884, Reward: 1.7740465658450066
# Max steps exceeded.
# Episode: 885, Reward: -4.617469722377409
# Max steps exceeded.
# Episode: 886, Reward: -4.293379559958484
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 887, Reward: -0.17509864938004446
# Max steps exceeded.
# Episode: 888, Reward: -5.29892842857893
# Max steps exceeded.
# Episode: 889, Reward: -6.9024589404226315
# Max steps exceeded.
# Episode: 890, Reward: -7.737534094607177
# Max steps exceeded.
# Episode: 891, Reward: 4.217030513840605
# Max steps exceeded.
# Episode: 892, Reward: -6.2787983225013875
# Max steps exceeded.
# Episode: 893, Reward: 2.1358649158266774
# Max steps exceeded.
# Episode: 894, Reward: -9.009733895198382
# Max steps exceeded.
# Episode: 895, Reward: 2.612257467661428
# Max steps exceeded.
# Episode: 896, Reward: -18.100477860514896
# Max steps exceeded.
# Episode: 897, Reward: -10.695968597199666
# Max steps exceeded.
# Episode: 898, Reward: -16.461857644955483
# Max steps exceeded.
# Episode: 899, Reward: -15.123922417102397
# Max steps exceeded.
# Episode: 900, Reward: -12.17767134486579
# Max steps exceeded.
# Episode: 901, Reward: -11.444164840257503
# Max steps exceeded.
# Episode: 902, Reward: -13.330956768562373
# Max steps exceeded.
# Episode: 903, Reward: -12.249858082298267
# Max steps exceeded.
# Episode: 904, Reward: -12.939713640407373
# Max steps exceeded.
# Episode: 905, Reward: -11.55193213300307
# Max steps exceeded.
# Episode: 906, Reward: 2.5686874474827714
# Max steps exceeded.
# Episode: 907, Reward: -11.194136839836595
# Max steps exceeded.
# Episode: 908, Reward: -12.678285050282382
# Max steps exceeded.
# Episode: 909, Reward: -9.090326423030852
# Max steps exceeded.
# Episode: 910, Reward: -4.311897538949071
# Max steps exceeded.
# Episode: 911, Reward: -6.431429895389042
# Max steps exceeded.
# Episode: 912, Reward: 0.03854464527350654
# Max steps exceeded.
# Episode: 913, Reward: -6.3541872818157
# Max steps exceeded.
# Episode: 914, Reward: -8.198716017317563
# Max steps exceeded.
# Episode: 915, Reward: -7.580981257886168
# Max steps exceeded.
# Episode: 916, Reward: -7.5794827665431805
# Max steps exceeded.
# Episode: 917, Reward: -4.12350502064239
# Max steps exceeded.
# Episode: 918, Reward: -3.203090280515835
# Max steps exceeded.
# Episode: 919, Reward: -13.48958844783003
# Max steps exceeded.
# Episode: 920, Reward: -5.758752791782401
# Max steps exceeded.
# Episode: 921, Reward: -18.788274775712726
# Max steps exceeded.
# Episode: 922, Reward: -3.7904120289086696
# Max steps exceeded.
# Episode: 923, Reward: -14.198189998490923
# Max steps exceeded.
# Episode: 924, Reward: -9.760030185561284
# Max steps exceeded.
# Episode: 925, Reward: -18.76587402072344
# Max steps exceeded.
# Episode: 926, Reward: -18.939231700053124
# Max steps exceeded.
# Episode: 927, Reward: 2.599908467131649
# Max steps exceeded.
# Episode: 928, Reward: -17.882746096935833
# Max steps exceeded.
# Episode: 929, Reward: -19.099764374061323
# Max steps exceeded.
# Episode: 930, Reward: -4.084336427325963
# Max steps exceeded.
# Episode: 931, Reward: -3.739489398313152
# Max steps exceeded.
# Episode: 932, Reward: -9.589796836785442
# Max steps exceeded.
# Episode: 933, Reward: -16.194860340487573
# Max steps exceeded.
# Episode: 934, Reward: -0.8753305379842515
# Max steps exceeded.
# Episode: 935, Reward: -2.3792953735922437
# Max steps exceeded.
# Episode: 936, Reward: -10.676407141550332
# Max steps exceeded.
# Episode: 937, Reward: -10.763783884511545
# Max steps exceeded.
# Episode: 938, Reward: -4.601556375173653
# Max steps exceeded.
# Episode: 939, Reward: -18.006653958578486
# Max steps exceeded.
# Episode: 940, Reward: -9.40769747347485
# Max steps exceeded.
# Episode: 941, Reward: -12.486984566553026
# Max steps exceeded.
# Episode: 942, Reward: -10.92324792551621
# Max steps exceeded.
# Episode: 943, Reward: 0.9464856871642047
# Max steps exceeded.
# Episode: 944, Reward: -10.328209833969018
# Max steps exceeded.
# Episode: 945, Reward: -10.012900320228058
# Max steps exceeded.
# Episode: 946, Reward: 4.516119531665024
# Max steps exceeded.
# Episode: 947, Reward: -2.7043760342820065
# Max steps exceeded.
# Episode: 948, Reward: 2.0680718770574513
# Max steps exceeded.
# Episode: 949, Reward: -10.400340979616574
# Max steps exceeded.
# Episode: 950, Reward: 1.875594603144486
# Max steps exceeded.
# Episode: 951, Reward: 1.250145482541214
# Max steps exceeded.
# Episode: 952, Reward: -9.089624330060184
# Max steps exceeded.
# Episode: 953, Reward: -5.5034171125170435
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 954, Reward: 0.7222931381059158
# Max steps exceeded.
# Episode: 955, Reward: -9.801809368686612
# Max steps exceeded.
# Episode: 956, Reward: -5.001578181013297
# Max steps exceeded.
# Episode: 957, Reward: 2.6381575285477603
# Max steps exceeded.
# Episode: 958, Reward: -10.50896738191019
# Max steps exceeded.
# Episode: 959, Reward: 2.923339955609623
# Max steps exceeded.
# Episode: 960, Reward: -1.1692479765694581
# Max steps exceeded.
# Episode: 961, Reward: -6.441665176305492
# Max steps exceeded.
# Episode: 962, Reward: 2.4663899364553914
# Max steps exceeded.
# Episode: 963, Reward: -13.604801815510537
# Max steps exceeded.
# Episode: 964, Reward: 2.9536041411985177
# Max steps exceeded.
# Episode: 965, Reward: -9.801778274795337
# Max steps exceeded.
# Episode: 966, Reward: -12.787773915439955
# Max steps exceeded.
# Episode: 967, Reward: 2.258568040066964
# Max steps exceeded.
# Episode: 968, Reward: -12.057036452676176
# Max steps exceeded.
# Episode: 969, Reward: -10.210023342435875
# Max steps exceeded.
# Episode: 970, Reward: -9.525926432908411
# Max steps exceeded.
# Episode: 971, Reward: 1.8181682918803417
# Max steps exceeded.
# Episode: 972, Reward: -4.723207782067475
# Max steps exceeded.
# Episode: 973, Reward: -15.974710022379806
# Max steps exceeded.
# Episode: 974, Reward: -13.353459561267321
# Max steps exceeded.
# Episode: 975, Reward: 2.5148726086553808
# Max steps exceeded.
# Episode: 976, Reward: -14.382162695113452
# Max steps exceeded.
# Episode: 977, Reward: -10.910004612513662
# Max steps exceeded.
# Episode: 978, Reward: -13.772317967272121
# Max steps exceeded.
# Episode: 979, Reward: -12.426784718041956
# Max steps exceeded.
# Episode: 980, Reward: -11.179574501785183
# Max steps exceeded.
# Episode: 981, Reward: -12.996799447778383
# Max steps exceeded.
# Episode: 982, Reward: -13.626513378529186
# Max steps exceeded.
# Episode: 983, Reward: -9.416008054325008
# Max steps exceeded.
# Episode: 984, Reward: -9.010460622826946
# Max steps exceeded.
# Episode: 985, Reward: -9.628115596275858
# Max steps exceeded.
# Episode: 986, Reward: -7.828135490581521
# Max steps exceeded.
# Episode: 987, Reward: -12.811979372015239
# Max steps exceeded.
# Episode: 988, Reward: -12.492612383763978
# Max steps exceeded.
# Episode: 989, Reward: -8.773199638721636
# Max steps exceeded.
# Episode: 990, Reward: -14.38684310612327
# Max steps exceeded.
# Episode: 991, Reward: -15.622652140908093
# Max steps exceeded.
# Episode: 992, Reward: -12.561145144013103
# Max steps exceeded.
# Episode: 993, Reward: -20.148275384060117
# Max steps exceeded.
# Episode: 994, Reward: -12.717127280931887
# Max steps exceeded.
# Episode: 995, Reward: -11.188767681985208
# Max steps exceeded.
# Episode: 996, Reward: -13.192962811691327
# Max steps exceeded.
# Episode: 997, Reward: -12.263722200419336
# Max steps exceeded.
# Episode: 998, Reward: -8.623793751900061
# Max steps exceeded.
# Episode: 999, Reward: -12.965099021805173

# %% [markdown]
# This code defines an objective function `objective(trial)` for hyperparameter optimization using Optuna. The objective function aims to find optimal hyperparameters for the Q-learning algorithm implemented in the context of the `UAVEnv` environment and the `QNetwork` neural network architecture.
#
# ### Objective Function
# - The `objective` function takes a `trial` object as input, which is used to suggest hyperparameter values for optimization.
# - Hyperparameters to be optimized:
#   - Learning rate (`learning_rate`): Suggested within a log-uniform distribution between 1e-5 and 1e-2.
#   - Batch size (`batch_size`): Suggested from a categorical set of values `[32, 64, 128]`.
#   - Epsilon (`epsilon`): Suggested within a uniform distribution between 0.01 and 0.2.
#   - Gamma (`gamma`): Suggested within a uniform distribution between 0.9 and 0.99.
#
# ### Model Setup
# - The `UAVEnv` environment is initialized, and the number of actions (`num_actions`) is obtained from the environment.
# - `QNetwork` and `target_network` instances are created based on the `QNetwork` class.
# - The weights of the `target_network` are set to match those of the `q_network`.
#
# ### Training Setup
# - Adam optimizer with the suggested learning rate is used.
# - A replay buffer (`replay_buffer`) of maximum length 10,000 is created.
# - `total_steps` and `target_update_freq` variables are initialized for training control.
# - The number of episodes (`num_episodes`) is set to 50 for faster trials.
#
# ### Training Loop
# - The training loop runs for `num_episodes` episodes.
# - Within each episode:
#   - The environment is reset, and the initial state is obtained.
#   - The episode continues until termination, and within each step:
#     - An action is chosen using an epsilon-greedy policy.
#     - The chosen action is applied to the environment, and the next state, reward, and termination signal are obtained.
#     - Transitions are stored in the replay buffer.
#     - If the replay buffer contains enough transitions, a minibatch is sampled, and the Q-network is updated.
#     - The target network is periodically updated to match the Q-network.
#
# ### Objective Evaluation
# - The objective function returns the average reward over the last 10 episodes (`average_reward`) as the optimization metric.

# %%
# Assuming UAVEnv and QNetwork are already defined as per your existing code.

def objective(trial):
    # Environment setup
    env = UAVEnv()
    num_actions = env.action_space.n

    # Suggest values for the hyperparameters
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    epsilon = trial.suggest_uniform('epsilon', 0.01, 0.2)
    gamma = trial.suggest_uniform('gamma', 0.9, 0.99)

    # Model setup
    q_network = QNetwork(num_actions)
    target_network = QNetwork(num_actions)
    target_network.set_weights(q_network.get_weights())

    # Optimizer setup
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    replay_buffer = deque(maxlen=10000)
    total_steps = 0
    target_update_freq = 100
    num_episodes = 50  # Reduced number of episodes for faster trials

    episode_rewards = []

    for episode in range(num_episodes):
        state = env.reset()
        episode_reward = 0
        done = False

        while not done:
            if np.random.rand() < epsilon:
                action = np.random.randint(num_actions)
            else:
                q_values = q_network(np.expand_dims(state, axis=0))
                action = np.argmax(q_values)

            next_state, reward, done, _ = env.step(action)
            episode_reward += reward

            replay_buffer.append((state, action, reward, next_state, done))
            state = next_state

            if len(replay_buffer) >= batch_size:
                minibatch = random.sample(replay_buffer, batch_size)
                states, actions, rewards, next_states, dones = zip(*minibatch)

                next_q_values = target_network(np.array(next_states))
                max_next_q_values = np.max(next_q_values, axis=1)
                targets = np.array(rewards) + (1 - np.array(dones)) * gamma * max_next_q_values

                with tf.GradientTape() as tape:
                    q_values = q_network(np.array(states))
                    selected_q_values = tf.reduce_sum(q_values * tf.one_hot(actions, num_actions), axis=1)
                    loss = tf.reduce_mean(tf.square(targets - selected_q_values))
                grads = tape.gradient(loss, q_network.trainable_variables)
                optimizer.apply_gradients(zip(grads, q_network.trainable_variables))

                if total_steps % target_update_freq == 0:
                    target_network.set_weights(q_network.get_weights())

            total_steps += 1

        episode_rewards.append(episode_reward)

    average_reward = np.mean(episode_rewards[-10:])  # Focus on the last 10 episodes' performance
    return average_reward

# %% [markdown]
# This code block initializes an Optuna study object, conducts hyperparameter optimization using the defined objective function, and prints the best trial along with its corresponding hyperparameters.
#
# ### Hyperparameter Optimization
# - A study object named `study` is created using `optuna.create_study()`, specifying the optimization direction as 'maximize' since the objective function aims to maximize the average reward.
# - Optimization is performed using the `study.optimize()` function, which takes the defined `objective` function as input and conducts a specified number of trials (`n_trials`).
# - In each trial, the objective function is executed with suggested hyperparameters, and the average reward is used as the optimization metric.
#
# ### Best Trial Information
# - After optimization, the best trial information is printed.
# - The best trial is obtained using `study.best_trial`.
# - The value of the best trial (i.e., the maximum average reward achieved) is printed.
# - The hyperparameters corresponding to the best trial are printed, showing each hyperparameter's name and value.

# %%
# Create a study object and perform optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print('Best trial:')
trial = study.best_trial
print(f'Value: {trial.value}')

print('Best hyperparameters:')
for key, value in trial.params.items():
    print(f"{key}: {value}")
# Out:
# [I 2024-04-30 17:40:53,234] A new study created in memory with name: no-name-21338303-8546-4aa7-8736-93bc97d1c8c2
# C:\Users\ammar\myuav\Lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# C:\Users\ammar\AppData\Local\Temp\ipykernel_21324\2010009686.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
# C:\Users\ammar\AppData\Local\Temp\ipykernel_21324\2010009686.py:19: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   epsilon = trial.suggest_uniform('epsilon', 0.01, 0.2)
# C:\Users\ammar\AppData\Local\Temp\ipykernel_21324\2010009686.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.9, 0.99)
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 17:42:38,522] Trial 0 finished with value: 2.541343690102162 and parameters: {'learning_rate': 3.323992718342429e-05, 'batch_size': 64, 'epsilon': 0.0538072715617546, 'gamma': 0.900839143031443}. Best is trial 0 with value: 2.541343690102162.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# [I 2024-04-30 17:44:13,596] Trial 1 finished with value: 4.188442443999274 and parameters: {'learning_rate': 4.2730017607200704e-05, 'batch_size': 128, 'epsilon': 0.0374368669757426, 'gamma': 0.924465489649662}. Best is trial 1 with value: 4.188442443999274.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 17:46:06,799] Trial 2 finished with value: -6.102661279556038 and parameters: {'learning_rate': 1.853862159603044e-05, 'batch_size': 64, 'epsilon': 0.10322008464502383, 'gamma': 0.9670866906797358}. Best is trial 1 with value: 4.188442443999274.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Goal reached!
# [I 2024-04-30 17:48:12,720] Trial 3 finished with value: 41.952776229707716 and parameters: {'learning_rate': 0.0003284879844988309, 'batch_size': 128, 'epsilon': 0.03116170747631085, 'gamma': 0.9886187264407758}. Best is trial 3 with value: 41.952776229707716.
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 17:50:01,346] Trial 4 finished with value: 0.0073158866512909706 and parameters: {'learning_rate': 0.0014434834006460864, 'batch_size': 32, 'epsilon': 0.0607987159172077, 'gamma': 0.914161646935573}. Best is trial 3 with value: 41.952776229707716.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 17:52:22,921] Trial 5 finished with value: -3.8572870018670797 and parameters: {'learning_rate': 0.006994072727973096, 'batch_size': 32, 'epsilon': 0.09486251072150116, 'gamma': 0.9760351005367399}. Best is trial 3 with value: 41.952776229707716.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# [I 2024-04-30 17:54:16,924] Trial 6 finished with value: 16.02577845566247 and parameters: {'learning_rate': 0.0011534908070651557, 'batch_size': 32, 'epsilon': 0.03824722270784672, 'gamma': 0.9720010646243435}. Best is trial 3 with value: 41.952776229707716.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# [I 2024-04-30 17:56:13,459] Trial 7 finished with value: -12.621910573597315 and parameters: {'learning_rate': 0.003297061335190021, 'batch_size': 32, 'epsilon': 0.1753101664595651, 'gamma': 0.9735072339186551}. Best is trial 3 with value: 41.952776229707716.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 17:57:54,168] Trial 8 finished with value: 7.294953737410114 and parameters: {'learning_rate': 5.4033233261380666e-05, 'batch_size': 128, 'epsilon': 0.01837831566213371, 'gamma': 0.9243330136515272}. Best is trial 3 with value: 41.952776229707716.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# [I 2024-04-30 17:59:30,143] Trial 9 finished with value: -29.83824999099604 and parameters: {'learning_rate': 0.0016268073582716553, 'batch_size': 64, 'epsilon': 0.11857280877706965, 'gamma': 0.9291249229036302}. Best is trial 3 with value: 41.952776229707716.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# [I 2024-04-30 18:01:01,837] Trial 10 finished with value: 38.09249431513065 and parameters: {'learning_rate': 0.00021726593856637313, 'batch_size': 128, 'epsilon': 0.1924915114641669, 'gamma': 0.9889809452897844}. Best is trial 3 with value: 41.952776229707716.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 18:02:13,776] Trial 11 finished with value: 3.2384290688976387 and parameters: {'learning_rate': 0.0002375623337884694, 'batch_size': 128, 'epsilon': 0.19574744431357993, 'gamma': 0.9518407959090085}. Best is trial 3 with value: 41.952776229707716.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 18:03:07,340] Trial 12 finished with value: 18.623133547540352 and parameters: {'learning_rate': 0.0002521375874222203, 'batch_size': 128, 'epsilon': 0.1476366653572418, 'gamma': 0.9860749479095015}. Best is trial 3 with value: 41.952776229707716.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# [I 2024-04-30 18:04:58,699] Trial 13 finished with value: 37.64292086684794 and parameters: {'learning_rate': 0.000516349432427948, 'batch_size': 128, 'epsilon': 0.1568226019868642, 'gamma': 0.9897336160729128}. Best is trial 3 with value: 41.952776229707716.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# [I 2024-04-30 18:06:40,013] Trial 14 finished with value: 0.01690550816699843 and parameters: {'learning_rate': 0.00011402387277022082, 'batch_size': 128, 'epsilon': 0.07955220426192797, 'gamma': 0.9541080673057464}. Best is trial 3 with value: 41.952776229707716.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# ...
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 21:29:07,252] Trial 94 finished with value: -23.487171233248404 and parameters: {'learning_rate': 0.0026231687959184335, 'batch_size': 128, 'epsilon': 0.09598800543605256, 'gamma': 0.9850998217225329}. Best is trial 82 with value: 104.371021661684.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# [I 2024-04-30 21:30:39,621] Trial 95 finished with value: -7.633864636093132 and parameters: {'learning_rate': 0.0013360734837570309, 'batch_size': 128, 'epsilon': 0.1508035664987487, 'gamma': 0.9733343882095761}. Best is trial 82 with value: 104.371021661684.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# [I 2024-04-30 21:32:01,237] Trial 96 finished with value: 82.26400774653112 and parameters: {'learning_rate': 0.0009844424153672734, 'batch_size': 128, 'epsilon': 0.059277516477428974, 'gamma': 0.9687990077607629}. Best is trial 82 with value: 104.371021661684.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# [I 2024-04-30 21:34:34,839] Trial 97 finished with value: -5.252252937426171 and parameters: {'learning_rate': 0.004141230895536552, 'batch_size': 128, 'epsilon': 0.017715831997126195, 'gamma': 0.9693029568961776}. Best is trial 82 with value: 104.371021661684.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Goal reached!
# Goal reached!
# Goal reached!
# Max steps exceeded.
# Goal reached!
# Max steps exceeded.
# Max steps exceeded.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Max steps exceeded.
# [I 2024-04-30 21:36:23,898] Trial 98 finished with value: 61.98616833564355 and parameters: {'learning_rate': 0.0009864259353579135, 'batch_size': 32, 'epsilon': 0.057602776990385546, 'gamma': 0.9657546879424355}. Best is trial 82 with value: 104.371021661684.
# Goal reached!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# [I 2024-04-30 21:36:40,748] Trial 99 finished with value: 3.4981532894282337 and parameters: {'learning_rate': 0.0006948263848002696, 'batch_size': 32, 'epsilon': 0.04218077977929275, 'gamma': 0.9760054632218698}. Best is trial 82 with value: 104.371021661684.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Best trial:
# Value: 104.371021661684
# Best hyperparameters:
# learning_rate: 0.0005816786580355395
# batch_size: 128
# epsilon: 0.09940432873344196
# gamma: 0.9701913302399167

# %% [markdown]
# This code block initializes the environment and the model with hyperparameters optimized through Optuna. It then proceeds to train the model using the optimized hyperparameters.
#
# ### Setting Optimized Hyperparameters
# - The hyperparameters obtained from the optimization process are set:
#   - Learning rate: 0.0005816786580355395
#   - Batch size: 128
#   - Epsilon (exploration-exploitation trade-off parameter): 0.09940432873344196
#   - Gamma (discount factor): 0.9701913302399167
#
# ### Environment and Model Initialization
# - The environment (`UAVEnv`) is initialized to set up the simulation.
# - The Q-network model (`QNetwork`) is initialized with the number of possible actions in the environment.
#
# ### Optimizer Setup
# - The Adam optimizer is configured with the optimized learning rate.
#
# ### Replay Buffer and Training Setups
# - A replay buffer is initialized to store transitions for experience replay.
# - Other variables such as total steps, target update frequency, and the number of episodes for training are set up.
#
# ### Training Loop
# - The training loop iterates over the specified number of episodes.
# - Within each episode, the environment is reset, and the agent interacts with it.
# - The agent's action is selected based on an epsilon-greedy policy.
# - Transitions are stored in the replay buffer, and if it contains enough transitions, the Q-network is updated using a mini-batch from the replay buffer.
# - The target network is updated periodically to stabilize training.
# - Episode rewards are printed for monitoring training progress.

# %%
# Set optimized hyperparameters
learning_rate = 0.0005816786580355395
batch_size = 128
epsilon = 0.09940432873344196
gamma = 0.9701913302399167

# Initialize environment and model with optimized parameters
env = UAVEnv()
num_actions = env.action_space.n
q_network = QNetwork(num_actions)
target_network = QNetwork(num_actions)
target_network.set_weights(q_network.get_weights())

# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Replay buffer and other setups
replay_buffer = deque(maxlen=10000)
total_steps = 0
target_update_freq = 100
num_episodes = 1000  # Number of episodes for extended training

# Training loop with optimized hyperparameters
for episode in range(num_episodes):
    state = env.reset()
    episode_reward = 0
    done = False
    
    while not done:
        if np.random.rand() < epsilon:
            action = np.random.randint(num_actions)
        else:
            q_values = q_network(np.expand_dims(state, axis=0))
            action = np.argmax(q_values)

        next_state, reward, done, _ = env.step(action)
        episode_reward += reward

        replay_buffer.append((state, action, reward, next_state, done))
        state = next_state

        if len(replay_buffer) >= batch_size:
            minibatch = random.sample(replay_buffer, batch_size)
            states, actions, rewards, next_states, dones = zip(*minibatch)

            next_q_values = target_network(np.array(next_states))
            max_next_q_values = np.max(next_q_values, axis=1)
            targets = np.array(rewards) + (1 - np.array(dones)) * gamma * max_next_q_values

            with tf.GradientTape() as tape:
                q_values = q_network(np.array(states))
                selected_q_values = tf.reduce_sum(q_values * tf.one_hot(actions, num_actions), axis=1)
                loss = tf.reduce_mean(tf.square(targets - selected_q_values))
            grads = tape.gradient(loss, q_network.trainable_variables)
            optimizer.apply_gradients(zip(grads, q_network.trainable_variables))

            if total_steps % target_update_freq == 0:
                target_network.set_weights(q_network.get_weights())

        total_steps += 1

    print(f"Episode: {episode}, Reward: {episode_reward}")
# Out:
# Max steps exceeded.
# Episode: 0, Reward: 5.280459365151315
# Episode: 1, Reward: -91.85527225848875
# Max steps exceeded.
# Episode: 2, Reward: -2.7356789254727345
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode:
# Max steps exceeded.
# Episode: 656, Reward: 4.705632566642409
# Max steps exceeded.
# Episode: 657, Reward: 0.7165182444569567
# Goal reached!
# Episode: 658, Reward: 115.20974708366941
# Goal reached!
# Episode: 659, Reward: 116.0181654124173
# Goal reached!
# Episode: 660, Reward: 114.94865094724518
# Goal reached!
# Episode: 661, Reward: 115.64024098254907
# Goal reached!
# Episode: 662, Reward: 115.60879627299377
# Max steps exceeded.
# Episode: 663, Reward: -9.454481742550518
# Goal reached!
# Episode: 664, Reward: 113.91805786467123
# Goal reached!
# Episode: 665, Reward: 115.048865747227
# Goal reached!
# Episode: 666, Reward: 115.67325229698497
# Goal reached!
# Episode: 667, Reward: 116.11170735186877
# Goal reached!
# Episode: 668, Reward: 115.73219836095242
# Max steps exceeded.
# Episode: 669, Reward: -2.3292214195176313
# Max steps exceeded.
# Episode: 670, Reward: -8.8173158248946
# Goal reached!
# Episode: 671, Reward: 114.63375124286299
# Max steps exceeded.
# Episode: 672, Reward: -8.434014665693256
# Max steps exceeded.
# Episode: 673, Reward: 5.037851004401414
# Max steps exceeded.
# Episode: 674, Reward: 11.839421831222548
# Max steps exceeded.
# Episode: 675, Reward: -8.103406010064854
# Max steps exceeded.
# Episode: 676, Reward: -8.970914088133418
# Max steps exceeded.
# Episode: 677, Reward: -7.690203258297916
# Goal reached!
# Episode: 678, Reward: 115.68382473262535
# Max steps exceeded.
# Episode: 679, Reward: -9.32121839511278
# Max steps exceeded.
# Episode: 680, Reward: -5.944685130457572
# Max steps exceeded.
# Episode: 681, Reward: -3.6166584686471754
# Max steps exceeded.
# Episode: 682, Reward: -5.061060538600756
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 683, Reward: -4.191579497962951
# Max steps exceeded.
# Episode: 684, Reward: -6.471796444267384
# Max steps exceeded.
# Episode: 685, Reward: -3.0499335127602127
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 686, Reward: 3.3464454846076115
# Max steps exceeded.
# Episode: 687, Reward: -12.119170839709552
# Max steps exceeded.
# Episode: 688, Reward: -1.9613870378601002
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 689, Reward: 5.9508224572912
# Max steps exceeded.
# Episode: 690, Reward: -4.319809599142807
# Max steps exceeded.
# Episode: 691, Reward: -2.2735675772571513
# Max steps exceeded.
# Episode: 692, Reward: -4.765769542863051
# Max steps exceeded.
# Episode: 693, Reward: -1.8094847340157179
# Max steps exceeded.
# Episode: 694, Reward: -6.884230810746351
# Max steps exceeded.
# Episode: 695, Reward: -8.978896500250196
# Max steps exceeded.
# Episode: 696, Reward: -6.7046996062570035
# Max steps exceeded.
# Episode: 697, Reward: -3.008162550920197
# Max steps exceeded.
# Episode: 698, Reward: -8.731766805243351
# Max steps exceeded.
# Episode: 699, Reward: -7.604137523367886
# Max steps exceeded.
# Episode: 700, Reward: 1.4782244961804951
# Max steps exceeded.
# Episode: 701, Reward: -4.304784753782246
# Max steps exceeded.
# Episode: 702, Reward: 1.5775959083630648
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 703, Reward: 3.4642147267502486
# Max steps exceeded.
# Episode: 704, Reward: 3.808951027191488
# Max steps exceeded.
# Episode: 705, Reward: -2.5826234923462534
# Goal reached!
# Episode: 706, Reward: 112.64924610469285
# Max steps exceeded.
# Episode: 707, Reward: -5.6116663629904044
# Max steps exceeded.
# Episode: 708, Reward: -3.198718249799612
# Max steps exceeded.
# Episode: 709, Reward: -10.495036944340526
# Max steps exceeded.
# Episode: 710, Reward: -7.715254986260689
# Max steps exceeded.
# ...
# Episode: 749, Reward: -19.18298108176306
# Max steps exceeded.
# Episode: 750, Reward: -17.48657071237165
# Max steps exceeded.
# Episode: 751, Reward: -8.45191737970968
# Max steps exceeded.
# Episode: 752, Reward: -19.765439741180224
# Max steps exceeded.
# Episode: 753, Reward: -11.5368015330486
# Max steps exceeded.
# Episode: 754, Reward: -18.601575909698226
# Max steps exceeded.
# Episode: 755, Reward: -11.537354137411661
# Max steps exceeded.
# Episode: 756, Reward: -19.22766725970446
# Max steps exceeded.
# Episode: 757, Reward: -10.291552112409823
# Max steps exceeded.
# Episode: 758, Reward: -9.40978952443428
# Max steps exceeded.
# Episode: 759, Reward: -15.084099165526572
# Max steps exceeded.
# Episode: 760, Reward: -13.231037273321613
# Max steps exceeded.
# Episode: 761, Reward: -23.831634089094504
# Max steps exceeded.
# Episode: 762, Reward: -11.435719350856207
# Max steps exceeded.
# Episode: 763, Reward: -4.716703820260525
# Max steps exceeded.
# Episode: 764, Reward: -11.16202612731056
# Max steps exceeded.
# Episode: 765, Reward: -18.30454994984433
# Max steps exceeded.
# Episode: 766, Reward: -11.47250819041812
# Max steps exceeded.
# Episode: 767, Reward: -8.419669709277652
# Max steps exceeded.
# Episode: 768, Reward: -15.922778792468183
# Max steps exceeded.
# Episode: 769, Reward: -18.15338254370765
# Max steps exceeded.
# Episode: 770, Reward: -10.83431635692274
# Max steps exceeded.
# Episode: 771, Reward: -11.869910618704232
# Max steps exceeded.
# Episode: 772, Reward: -8.15639729121638
# Max steps exceeded.
# Episode: 773, Reward: -11.267266121830252
# Max steps exceeded.
# Episode: 774, Reward: -11.2643861277877
# Max steps exceeded.
# Episode: 775, Reward: -8.3625243864664
# Max steps exceeded.
# Episode: 776, Reward: -11.432104632195552
# Max steps exceeded.
# Episode: 777, Reward: -15.805568697429866
# Max steps exceeded.
# Episode: 778, Reward: -6.594464587311545
# Max steps exceeded.
# Episode: 779, Reward: -20.61731134514211
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 780, Reward: 4.205944438269192
# Max steps exceeded.
# Episode: 781, Reward: -23.92010750101395
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Max steps exceeded.
# Episode: 782, Reward: -6.124415943598936
# Collision detected! Taking avoidance measures.
# Collision detected! Taking avoidance measures.
# Collision with an obstacle!
# Episode: 783, Reward: 1.2901501837066127
# Max steps exceeded.
# Episode: 784, Reward: -15.225707675912576
# Max steps exceeded.
# Episode: 785, Reward: -10.710827531754962
# Max steps exceeded.
# Episode: 786, Reward: -24.434784897159865
# Max steps exceeded.
# Episode: 787, Reward: -10.244679529471833
# Max steps exceeded.
# Episode: 788, Reward: -15.804227946307133
# Max steps exceeded.
# Episode: 789, Reward: -8.984988021815122
# Max steps exceeded.
# Episode: 790, Reward: -15.38261470968139
# Max steps exceeded.
# Episode: 791, Reward: -10.439619042111325
#   - The function iterates over the specified number of episodes.
#   - Within each episode:
#     - The environment is reset, and the initial state is obtained.
#     - The agent interacts with the environment based on the Q-network's action selections.
#     - The episode terminates when a terminal state is reached.
#     - The total episode reward is calculated.
#   - After all episodes are completed, the average reward over the evaluation episodes is computed.
#   - The function prints the average reward as the evaluation result.
#
# ### Usage
# To evaluate a trained Q-network model, call this function with the trained model and the environment instance where evaluation will be performed. Optionally, you can specify the number of evaluation episodes.

# %%
# Evaluate trained model
def evaluate_model(env, q_network, num_episodes=10):
    episode_rewards = []
    for _ in range(num_episodes):
        state = env.reset()
        episode_reward = 0
        done = False
        while not done:
            q_values = q_network(np.expand_dims(state, axis=0))
            action = np.argmax(q_values)
            next_state, reward, done, _ = env.step(action)
            episode_reward += reward
            state = next_state
        episode_rewards.append(episode_reward)
    avg_reward = np.mean(episode_rewards)
    print(f"Average reward over {num_episodes} episodes: {avg_reward}")

# %% [markdown]
# This code block contains two main functions for evaluating and observing the behavior of a trained Q-network model in a given environment.
#
# ### Function: `evaluate_model(env, q_network, num_episodes=10)`
# - **Parameters**:
#   - `env`: The environment instance where the model will be evaluated.
#   - `q_network`: The Q-network model to be evaluated.
#   - `num_episodes`: The number of episodes to run for evaluation (default is 10).
#
# - **Evaluation Process**:
#   - The function iterates over the specified number of episodes.
#   - Within each episode:
#     - The environment is reset, and the initial state is obtained.
#     - The agent interacts with the environment based on the Q-network's action selections.
#     - The episode terminates when a terminal state is reached.
#     - The total episode reward is calculated.
#   - After all episodes are completed, the average reward over the evaluation episodes is computed.
#   - The function prints the average reward as the evaluation result.
#
# ### Function: `observe_behavior(env, q_network)`
# - **Parameters**:
#   - `env`: The environment instance where the model's behavior will be observed.
#   - `q_network`: The trained Q-network model whose behavior will be observed.
#
# - **Observation Process**:
#   - The function resets the environment and obtains the initial state.
#   - The agent iteratively interacts with the environment based on the Q-network's action selections.
#   - The environment's rendering is invoked after each action to observe the agent's behavior.
#   - The process continues until a terminal state is reached.
#
# ### Usage
# 1. Call `evaluate_model(env, q_network)` to assess the performance of the trained Q-network model in the specified environment.
# 2. Call `observe_behavior(env, q_network)` to observe the behavior of the trained model in the environment.

# %%
# Use trained q_network to act in environment and observe its behavior
def observe_behavior(env, q_network):
    state = env.reset()
    done = False
    while not done:
        q_values = q_network(np.expand_dims(state, axis=0))
        action = np.argmax(q_values)
        next_state, reward, done, _ = env.step(action)
        env.render()
        state = next_state

# Evaluate the trained model
evaluate_model(env, q_network)

# Observe the behavior of the trained model in the environment
observe_behavior(env, q_network)
# Out:
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Goal reached!
# Average reward over 10 episodes: 115.71881129863667
# Goal reached!

# %%
def observe_behavior(env, q_network, max_steps=1000):
    state = env.reset()
    done = False
    positions = []
    while not done and len(positions) < max_steps:
        q_values = q_network(np.expand_dims(state, axis=0))
        action = np.argmax(q_values)
        next_state, reward, done, _ = env.step(action)
        positions.append(env.state[:2])  # Record position (latitude and longitude)
        state = next_state
    return positions

def plot_path(positions, goal_position):
    positions = np.array(positions)
    plt.figure(figsize=(10, 10))
    plt.plot(positions[:, 0], positions[:, 1], label='UAV Path', color='blue')
    plt.scatter(goal_position[0], goal_position[1], c='red', s=100, label='Goal')
    plt.xlabel('Latitude')
    plt.ylabel('Longitude')
    plt.title('Path of UAV reaching the goal')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_path(positions, goal_position, obstacles=None, no_fly_zones=None):
    """
    Plot the path taken by the UAV.

    Parameters:
    - positions (list): List of positions visited by the UAV.
    - goal_position (tuple): Tuple representing the goal position (latitude, longitude).
    - obstacles (list): List of obstacle dictionaries.
    - no_fly_zones (list): List of no-fly zone dictionaries.
    """
    # Extract latitude and longitude from the goal position
    goal_latitude, goal_longitude, _ = goal_position

    # Plot positions
    plt.plot([pos[0] for pos in positions], [pos[1] for pos in positions], label='UAV Path', color='blue')

    # Plot goal position
    plt.scatter(goal_latitude, goal_longitude, c='red', s=100, label='Goal', alpha=0.5)

    # Plot obstacles
    if obstacles:
        for obstacle in obstacles:
            obstacle_type = obstacle.get('type')
            obstacle_position = obstacle.get('position')
            if obstacle_type == 'rectangle':
                # Extract latitude and longitude from the position tuple
                obstacle_latitude, obstacle_longitude, _ = obstacle_position
                plt.scatter(obstacle_latitude, obstacle_longitude, c='gray', marker='x', label='Obstacle', alpha=0.5)
            elif obstacle_type == 'circle':
                # Extract latitude and longitude from the position tuple
                obstacle_latitude, obstacle_longitude, _ = obstacle_position
                plt.scatter(obstacle_latitude, obstacle_longitude, c='gray', marker='o', label='Obstacle', alpha=0.5)
            elif obstacle_type == 'ellipse':
                # Extract latitude and longitude from the position tuple
                obstacle_latitude, obstacle_longitude, _ = obstacle_position
                plt.scatter(obstacle_latitude, obstacle_longitude, c='gray', marker='^', label='Obstacle', alpha=0.5)

    # Plot no-fly zones
    if no_fly_zones:
        for zone in no_fly_zones:
            zone_type = zone.get('type')
            zone_position = zone.get('position')
            if zone_type == 'rectangle':
                # Extract latitude and longitude from the position tuple
                zone_latitude, zone_longitude, _ = zone_position
                plt.scatter(zone_latitude, zone_longitude, c='purple', marker='s', label='No-Fly Zone', alpha=0.5)
            elif zone_type == 'circle':
                # Extract latitude and longitude from the position tuple
                zone_latitude, zone_longitude, _ = zone_position
                plt.scatter(zone_latitude, zone_longitude, c='purple', marker='o', label='No-Fly Zone', alpha=0.5)

    # Axis labels and title
    plt.xlabel('Latitude')
    plt.ylabel('Longitude')
    plt.title('UAV Navigation Path')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
positions = observe_behavior(env, q_network)
plot_path(positions, env.goal_position, obstacles=env.obstacles)
# Out:
# Goal reached!

# %% [markdown]
# **Training Both Algorithms together**
#
# # PPO Model
# # Creating a vectorized environment with 4 parallel environments
# ppo_env = make_vec_env(lambda: UAVEnv(), n_envs=4)
#
# # Initializing the PPO model with the MlpPolicy
# ppo_model = PPO("MlpPolicy",
#                 ppo_env,
#                 learning_rate=0.0003805913356107848,
#                 n_steps=64,
#                 batch_size=32,
#                 verbose=1)
#
# # Training the PPO model
# ppo_model.learn(total_timesteps=150000)
#
# # Evaluating the trained PPO agent
# ppo_mean_reward, _ = evaluate_policy(ppo_model, ppo_env, n_eval_episodes=20)
# print(f"PPO Mean reward: {ppo_mean_reward}")
#
# # Close the PPO environment when done
# ppo_env.close()
#
# # DDQN Model
# # Set optimized hyperparameters
# ddqn_learning_rate = 0.0005816786580355395
# ddqn_batch_size = 128
# ddqn_epsilon = 0.09940432873344196
# ddqn_gamma = 0.9701913302399167
#
# # Initialize environment and model with optimized parameters
# ddqn_env = UAVEnv()
# ddqn_num_actions = ddqn_env.action_space.n
# ddqn_q_network = QNetwork(ddqn_num_actions)
# ddqn_target_network = QNetwork(ddqn_num_actions)
# ddqn_target_network.set_weights(ddqn_q_network.get_weights())
#
# # Optimizer
# ddqn_optimizer = tf.keras.optimizers.Adam(learning_rate=ddqn_learning_rate)
#
# # Replay buffer and other setups
# ddqn_replay_buffer = deque(maxlen=10000)
# ddqn_total_steps = 0
# ddqn_target_update_freq = 100
# ddqn_num_episodes = 1000  # Number of episodes for extended training
#
# # Training loop with optimized hyperparameters for DDQN
# for ddqn_episode in range(ddqn_num_episodes):
#     ddqn_state = ddqn_env.reset()
#     ddqn_episode_reward = 0
#     ddqn_done = False
#
#     while not ddqn_done:
#         if np.random.rand() < ddqn_epsilon:
#             ddqn_action = np.random.randint(ddqn_num_actions)
#         else:
#             ddqn_q_values = ddqn_q_network(np.expand_dims(ddqn_state, axis=0))
#             ddqn_action = np.argmax(ddqn_q_values)
#
#         ddqn_next_state, ddqn_reward, ddqn_done, _ = ddqn_env.step(ddqn_action)
#         ddqn_episode_reward += ddqn_reward
#
#         ddqn_replay_buffer.append((ddqn_state, ddqn_action, ddqn_reward, ddqn_next_state, ddqn_done))
#         ddqn_state = ddqn_next_state
#
#         if len(ddqn_replay_buffer) >= ddqn_batch_size:
#             ddqn_minibatch = random.sample(ddqn_replay_buffer, ddqn_batch_size)
#             ddqn_states, ddqn_actions, ddqn_rewards, ddqn_next_states, ddqn_dones = zip(*ddqn_minibatch)
#
#             ddqn_next_q_values = ddqn_target_network(np.array(ddqn_next_states))
#             ddqn_max_next_q_values = np.max(ddqn_next_q_values, axis=1)
#             ddqn_targets = np.array(ddqn_rewards) + (1 - np.array(ddqn_dones)) * ddqn_gamma * ddqn_max_next_q_values
#
#             with tf.GradientTape() as ddqn_tape:
#                 ddqn_q_values = ddqn_q_network(np.array(ddqn_states))
#                 ddqn_selected_q_values = tf.reduce_sum(ddqn_q_values * tf.one_hot(ddqn_actions, ddqn_num_actions), axis=1)
#                 ddqn_loss = tf.reduce_mean(tf.square(ddqn_targets - ddqn_selected_q_values))
#             ddqn_grads = ddqn_tape.gradient(ddqn_loss, ddqn_q_network.trainable_variables)
#             ddqn_optimizer.apply_gradients(zip(ddqn_grads, ddqn_q_network.trainable_variables))
#
#             if ddqn_total_steps % ddqn_target_update_freq == 0:
#                 ddqn_target_network.set_weights(ddqn_q_network.get_weights())
#
#         ddqn_total_steps += 1
#
#     print(f"DDQN Episode: {ddqn_episode}, Reward: {ddqn_episode_reward}")
